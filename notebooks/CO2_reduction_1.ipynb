# %% [markdown]
# # Workflow for a multi-regional energy system
#
# In this application of the FINE framework, a multi-regional energy system is modeled and optimized.
#
# All classes which are available to the user are utilized and examples of the selection of different parameters within these classes are given.
#
# The workflow is structures as follows:
# 1. Required packages are imported and the input data path is set
# 2. An energy system model instance is created
# 3. Commodity sources are added to the energy system model
# 4. Commodity conversion components are added to the energy system model
# 5. Commodity storages are added to the energy system model
# 6. Commodity transmission components are added to the energy system model
# 7. Commodity sinks are added to the energy system model
# 8. The energy system model is optimized
# 9. Selected optimization results are presented

# %% [markdown]
# # 1. Import required packages and set input data path
#
# The FINE framework is imported which provides the required classes and functions for modeling the energy system.

# %%
import FINE as fn
import matplotlib.pyplot as plt
from getData import getData
import pandas as pd
import os

cwd = os.getcwd()
data = getData()

# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 2. Create an energy system model instance
#
# The structure of the energy system model is given by the considered locations, commodities, the number of time steps as well as the hours per time step.
#
# The commodities are specified by a unit (i.e. 'GW_electric', 'GW_H2lowerHeatingValue', 'Mio. t CO2/h') which can be given as an energy or mass unit per hour. Furthermore, the cost unit and length unit are specified.

# %%
locations = {'cluster_0', 'cluster_1', 'cluster_2', 'cluster_3', 'cluster_4', 'cluster_5', 'cluster_6', 'cluster_7'}
commodityUnitDict = {'electricity': r'GW$_{el}$', 'methane': r'GW$_{CH_{4},LHV}$', 'biogas': r'GW$_{biogas,LHV}$',
                     'CO2': r'Mio. t$_{CO_2}$/h', 'hydrogen': r'GW$_{H_{2},LHV}$'}
commodities = {'electricity', 'hydrogen', 'methane', 'biogas', 'CO2'}
numberOfTimeSteps=8760
hoursPerTimeStep=1

# %%
esM = fn.EnergySystemModel(locations=locations, commodities=commodities, numberOfTimeSteps=8760,
                           commodityUnitsDict=commodityUnitDict,
                           hoursPerTimeStep=1, costUnit='1e9 Euro', lengthUnit='km', verboseLogLevel=0)

# %%
# Values are [0.75, 0.8, 0.85, 0.9, 0.95, 1]
CO2_reductionTarget = 1

# %% [markdown]
# # 3. Add commodity sources to the energy system model

# %% [markdown]
# ## 3.1. Electricity sources

# %% [markdown]
# ### Wind onshore

# %%
esM.add(fn.Source(esM=esM, name='Wind (onshore)', commodity='electricity', hasCapacityVariable=True,
                  operationRateMax=data['Wind (onshore), operationRateMax'],
                  capacityMax=data['Wind (onshore), capacityMax'],
                  investPerCapacity=1.1, opexPerCapacity=1.1*0.02, interestRate=0.08,
                  economicLifetime=20))

# %% [markdown]
# Full load hours:

# %%
data['Wind (onshore), operationRateMax'].sum()
# Out:
# cluster_0    1572.003960
# cluster_1    2350.292663
# cluster_2    2374.507270
# cluster_3    2186.572278
# cluster_4    1572.650655
# cluster_5    1767.840650
# cluster_6    2719.564564
# cluster_7    1553.045964
# dtype: float64

# %% [markdown]
# ### Wind offshore

# %%
esM.add(fn.Source(esM=esM, name='Wind (offshore)', commodity='electricity', hasCapacityVariable=True,
                  operationRateMax=data['Wind (offshore), operationRateMax'],
                  capacityMax=data['Wind (offshore), capacityMax'],
                  investPerCapacity=2.3, opexPerCapacity=2.3*0.02, interestRate=0.08,
                  economicLifetime=20))

# %% [markdown]
# Full load hours:

# %%
data['Wind (offshore), operationRateMax'].sum()
# Out:
# cluster_0       0.000000
# cluster_1    4435.420314
# cluster_2    4301.655834
# cluster_3    3902.391858
# cluster_4       0.000000
# cluster_5       0.000000
# cluster_6    4609.508396
# cluster_7       0.000000
# dtype: float64

# %% [markdown]
# ### PV

# %%
esM.add(fn.Source(esM=esM, name='PV', commodity='electricity', hasCapacityVariable=True,
                  operationRateMax=data['PV, operationRateMax'], capacityMax=data['PV, capacityMax'],
                  investPerCapacity=0.65, opexPerCapacity=0.65*0.02, interestRate=0.08,
                  economicLifetime=25))

# %% [markdown]
# Full load hours:

# %%
data['PV, operationRateMax'].sum()
# Out:
# cluster_0    1113.216464
# cluster_1    1053.579422
# cluster_2    1058.005181
# cluster_3    1079.872237
# cluster_4    1140.407380
# cluster_5    1051.848141
# cluster_6    1069.843344
# cluster_7    1085.697466
# dtype: float64

# %% [markdown]
# ### Exisisting run-of-river hydroelectricity plants

# %%
esM.add(fn.Source(esM=esM, name='Existing run-of-river plants', commodity='electricity',
                  hasCapacityVariable=True,
                  operationRateFix=data['Existing run-of-river plants, operationRateFix'], tsaWeight=0.01,
                  capacityFix=data['Existing run-of-river plants, capacityFix'],
                  investPerCapacity=0, opexPerCapacity=0.208))

# %% [markdown]
# ## 3.2. Methane (natural gas and biogas)

# %% [markdown]
# ### Natural gas

# %%
esM.add(fn.Source(esM=esM, name='Natural gas purchase', commodity='methane',
                  hasCapacityVariable=False, commodityCost=0.0331*1e-3))

# %% [markdown]
# ### Biogas

# %%
esM.add(fn.Source(esM=esM, name='Biogas purchase', commodity='biogas',
                  operationRateMax=data['Biogas, operationRateMax'], hasCapacityVariable=False,
                  commodityCost=0.05409*1e-3))

# %% [markdown]
# # 4. Add conversion components to the energy system model

# %% [markdown]
# ### Combined cycle gas turbine plants

# %%
esM.add(fn.Conversion(esM=esM, name='CCGT plants (methane)', physicalUnit=r'GW$_{el}$',
                      commodityConversionFactors={'electricity':1, 'methane':-1/0.6, 'CO2':201*1e-6/0.6},
                      hasCapacityVariable=True,
                      investPerCapacity=0.65, opexPerCapacity=0.021, interestRate=0.08,
                      economicLifetime=33))

# %% [markdown]
# ### New combined cycle gas turbine plants for biogas

# %%
esM.add(fn.Conversion(esM=esM, name='New CCGT plants (biogas)', physicalUnit=r'GW$_{el}$',
                      commodityConversionFactors={'electricity':1, 'biogas':-1/0.63},
                      hasCapacityVariable=True, 
                      investPerCapacity=0.7, opexPerCapacity=0.021, interestRate=0.08,
                      economicLifetime=33))

# %% [markdown]
# ### New combined cycly gas turbines for hydrogen

# %%
esM.add(fn.Conversion(esM=esM, name='New CCGT plants (hydrogen)', physicalUnit=r'GW$_{el}$',
                      commodityConversionFactors={'electricity':1, 'hydrogen':-1/0.63},
                      hasCapacityVariable=True, 
                      investPerCapacity=0.7, opexPerCapacity=0.021, interestRate=0.08,
                      economicLifetime=33))

# %% [markdown]
# ### Electrolyzers

# %%
esM.add(fn.Conversion(esM=esM, name='Electrolyzer', physicalUnit=r'GW$_{el}$',
                      commodityConversionFactors={'electricity':-1, 'hydrogen':0.7},
                      hasCapacityVariable=True, 
                      investPerCapacity=0.5, opexPerCapacity=0.5*0.025, interestRate=0.08,
                      economicLifetime=10))

# %% [markdown]
# ### rSOC

# %%
capexRSOC=1.5

esM.add(fn.Conversion(esM=esM, name='rSOEC', physicalUnit=r'GW$_{el}$', linkedConversionCapacityID='rSOC',
                      commodityConversionFactors={'electricity':-1, 'hydrogen':0.6},
                      hasCapacityVariable=True, 
                      investPerCapacity=capexRSOC/2, opexPerCapacity=capexRSOC*0.02/2, interestRate=0.08,
                      economicLifetime=10))

esM.add(fn.Conversion(esM=esM, name='rSOFC', physicalUnit=r'GW$_{el}$', linkedConversionCapacityID='rSOC',
                      commodityConversionFactors={'electricity':1, 'hydrogen':-1/0.6},
                      hasCapacityVariable=True, 
                      investPerCapacity=capexRSOC/2, opexPerCapacity=capexRSOC*0.02/2, interestRate=0.08,
                      economicLifetime=10))

# %% [markdown]
# # 5. Add commodity storages to the energy system model

# %% [markdown]
# ## 5.1. Electricity storage

# %% [markdown]
# ### Lithium ion batteries
#
# The self discharge of a lithium ion battery is here described as 3% per month. The self discharge per hours is obtained using the equation (1-$\text{selfDischarge}_\text{hour})^{30*24\text{h}} = 1-\text{selfDischarge}_\text{month}$.

# %%
esM.add(fn.Storage(esM=esM, name='Li-ion batteries', commodity='electricity',
                   hasCapacityVariable=True, chargeEfficiency=0.95,
                   cyclicLifetime=10000, dischargeEfficiency=0.95, selfDischarge=1-(1-0.03)**(1/(30*24)),
                   chargeRate=1, dischargeRate=1, doPreciseTsaModeling=False,
                   investPerCapacity=0.151, opexPerCapacity=0.002, interestRate=0.08,
                   economicLifetime=22))

# %% [markdown]
# ## 5.2. Hydrogen storage

# %% [markdown]
# ### Hydrogen filled salt caverns
# The maximum capacity is here obtained by: dividing the given capacity (which is given for methane) by the lower heating value of methane and then multiplying it with the lower heating value of hydrogen.

# %%
esM.add(fn.Storage(esM=esM, name='Salt caverns (hydrogen)', commodity='hydrogen',
                   hasCapacityVariable=True, capacityVariableDomain='continuous',
                   capacityPerPlantUnit=133,
                   chargeRate=1/470.37, dischargeRate=1/470.37, sharedPotentialID='Existing salt caverns',
                   stateOfChargeMin=0.33, stateOfChargeMax=1, capacityMax=data['Salt caverns (hydrogen), capacityMax'],
                   investPerCapacity=0.00011, opexPerCapacity=0.00057, interestRate=0.08,
                   economicLifetime=30))

# %% [markdown]
# ## 5.3. Methane storage

# %% [markdown]
# ### Methane filled salt caverns

# %%
esM.add(fn.Storage(esM=esM, name='Salt caverns (biogas)', commodity='biogas',
                   hasCapacityVariable=True, capacityVariableDomain='continuous',
                   capacityPerPlantUnit=443,
                   chargeRate=1/470.37, dischargeRate=1/470.37, sharedPotentialID='Existing salt caverns',
                   stateOfChargeMin=0.33, stateOfChargeMax=1, capacityMax=data['Salt caverns (methane), capacityMax'],
                   investPerCapacity=0.00004, opexPerCapacity=0.00001, interestRate=0.08,
                   economicLifetime=30))

# %% [markdown]
# ## 5.4 Pumped hydro storage

# %% [markdown]
# ### Pumped hydro storage

# %%
esM.add(fn.Storage(esM=esM, name='Pumped hydro storage', commodity='electricity',
                   chargeEfficiency=0.88, dischargeEfficiency=0.88,
                   hasCapacityVariable=True, selfDischarge=1-(1-0.00375)**(1/(30*24)),
                   chargeRate=0.16, dischargeRate=0.12, capacityFix=data['Pumped hydro storage, capacityFix'],
                   investPerCapacity=0, opexPerCapacity=0.000153))

# %% [markdown]
# # 6. Add commodity transmission components to the energy system model

# %% [markdown]
# ## 6.1. Electricity transmission

# %% [markdown]
# ### AC cables

# %% [markdown]
# esM.add(fn.LinearOptimalPowerFlow(esM=esM, name='AC cables', commodity='electricity',
#                                   hasCapacityVariable=True, capacityFix=data['AC cables, capacityFix'],
#                                   reactances=data['AC cables, reactances']))

# %%
esM.add(fn.Transmission(esM=esM, name='AC cables', commodity='electricity',
                                  hasCapacityVariable=True, capacityFix=data['AC cables, capacityFix']))
# Out:
# The distances of a component are set to a normalized value of 1.

# %% [markdown]
# ### DC cables

# %%
esM.add(fn.Transmission(esM=esM, name='DC cables', commodity='electricity', losses=data['DC cables, losses'],
                        distances=data['DC cables, distances'],
                        hasCapacityVariable=True, capacityFix=data['DC cables, capacityFix']))

# %% [markdown]
# ## 6.2 Methane transmission

# %% [markdown]
# ### Methane pipeline

# %%
esM.add(fn.Transmission(esM=esM, name='Pipelines (biogas)', commodity='biogas', 
                        distances=data['Pipelines, distances'],
                        hasCapacityVariable=True, hasIsBuiltBinaryVariable=True, bigM=300,
                        locationalEligibility=data['Pipelines, eligibility'],
                        capacityMax=data['Pipelines, eligibility']*15, sharedPotentialID='pipelines',
                        investPerCapacity=0.000037, investIfBuilt=0.000314,
                        interestRate=0.08, economicLifetime=40))

# %% [markdown]
# ## 6.3 Hydrogen transmission

# %% [markdown]
# ### Hydrogen pipelines

# %%
esM.add(fn.Transmission(esM=esM, name='Pipelines (hydrogen)', commodity='hydrogen',
                        distances=data['Pipelines, distances'],
                        hasCapacityVariable=True, hasIsBuiltBinaryVariable=True, bigM=300,
                        locationalEligibility=data['Pipelines, eligibility'],
                        capacityMax=data['Pipelines, eligibility']*15, sharedPotentialID='pipelines',
                        investPerCapacity=0.000177, investIfBuilt=0.00033,
                        interestRate=0.08, economicLifetime=40))

# %% [markdown]
# # 7. Add commodity sinks to the energy system model

# %% [markdown]
# ## 7.1. Electricity sinks

# %% [markdown]
# ### Electricity demand

# %%
esM.add(fn.Sink(esM=esM, name='Electricity demand', commodity='electricity',
                hasCapacityVariable=False, operationRateFix=data['Electricity demand, operationRateFix']))

# %% [markdown]
# ## 7.2. Hydrogen sinks

# %% [markdown]
# ### Fuel cell electric vehicle (FCEV) demand

# %%
FCEV_penetration=0.5
esM.add(fn.Sink(esM=esM, name='Hydrogen demand', commodity='hydrogen', hasCapacityVariable=False,
                operationRateFix=data['Hydrogen demand, operationRateFix']*FCEV_penetration))

# %% [markdown]
# ## 7.3. CO2 sinks

# %% [markdown]
# ### CO2 exiting the system's boundary

# %%
esM.add(fn.Sink(esM=esM, name='CO2 to enviroment', commodity='CO2',
                hasCapacityVariable=False, commodityLimitID='CO2 limit', yearlyLimit=366*(1-CO2_reductionTarget)))

# %% [markdown]
# # 8. Optimize energy system model

# %% [markdown]
# All components are now added to the model and the model can be optimized. If the computational complexity of the optimization should be reduced, the time series data of the specified components can be clustered before the optimization and the parameter timeSeriesAggregation is set to True in the optimize call.

# %%
esM.cluster(numberOfTypicalPeriods=7)
# Out:
# Clustering time series data with 7 typical periods and 24 time steps per period...
# 		(1.0890 sec)
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\tsam\timeseriesaggregation.py:897: UserWarning:Something went wrong: At least one maximal value of the aggregated time series exceeds the maximal value the input time series

# %%
esM.optimize(timeSeriesAggregation=True, optimizationSpecs='OptimalityTol=1e-3 method=2 cuts=0', solver="gurobi")
# Out:
# Time series aggregation specifications:
# Number of typical periods:7, number of time steps per period:24
#
# Declaring sets, variables and constraints for SourceSinkModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.4525 sec)
#
# Declaring sets, variables and constraints for ConversionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.1285 sec)
#
# Declaring sets, variables and constraints for StorageModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(1.8270 sec)
#
# Declaring sets, variables and constraints for TransmissionModel
# 	declaring sets...
# 	declaring variables...
# 	declaring constraints...
# 		(0.4500 sec)
#
# Declaring shared potential constraint...
# 		(0.0021 sec)
#
# Declaring linked component quantity constraint...
# 		(0.0005 sec)
#
# Declaring commodity balances...
# 		(0.5720 sec)
#
# 		(0.0000 sec)
#
# Declaring objective function...
# 		(0.2795 sec)
#
# Academic license - for non-commercial use only - expires 2021-12-30
# Using license file C:\Users\Paul\gurobi.lic
# Read LP format model from file C:\Users\Paul\AppData\Local\Temp\tmpfv_esp36.pyomo.lp
# Reading time = 0.38 seconds
# x96946: 85942 rows, 55618 columns, 264787 nonzeros
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Changed value of parameter Threads to 3
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Parameter logfile unchanged
#    Value:   Default:
# Changed value of parameter OptimalityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Changed value of parameter method to 2
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Changed value of parameter cuts to 0
#    Prev: -1  Min: -1  Max: 3  Default: -1
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 3 threads
# Optimize a model with 85942 rows, 55618 columns and 264787 nonzeros
# Model fingerprint: 0x1b05a44c
# Variable types: 55566 continuous, 52 integer (52 binary)
# Coefficient statistics:
#   Matrix range     [2e-06, 5e+02]
#   Objective range  [1e-05, 3e-01]
#   Bounds range     [1e+00, 1e+05]
#   RHS range        [4e-02, 3e+01]
# Presolve removed 24794 rows and 13791 columns
# Presolve time: 0.37s
# Presolved: 61148 rows, 41827 columns, 212766 nonzeros
# Variable types: 41801 continuous, 26 integer (26 binary)
# Root barrier log...
#
# Ordering time: 0.81s
#
# Barrier statistics:
#  Dense cols : 196
#  Free vars  : 1288
#  AA' NZ     : 1.235e+06
#  Factor NZ  : 6.968e+06 (roughly 100 MBytes of memory)
#  Factor Ops : 3.826e+09 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.66854727e+05 -2.39479752e+06  1.97e+06 1.38e-02  2.28e+03     2s
#    1   4.01885100e+05 -2.31120299e+06  1.38e+06 2.05e-01  1.48e+03     2s
#    2   2.95292423e+05 -2.06921158e+06  9.48e+05 9.30e-02  9.75e+02     2s
#    3   1.01043865e+05 -1.56527228e+06  2.47e+05 2.67e-02  2.78e+02     2s
#    4   3.78851593e+04 -7.16794036e+05  4.10e+04 1.60e-03  4.46e+01     2s
#    5   2.24433799e+04 -2.18344648e+05  1.04e+04 8.37e-04  1.08e+01     2s
#    6   9.42576498e+03 -1.31895806e+05  1.59e+03 4.32e-04  2.57e+00     2s
#    7   4.09425539e+03 -2.98446521e+04  2.27e+02 4.66e-04  4.12e-01     3s
#    8   1.47591846e+03 -8.57793254e+03  5.22e+01 1.43e-04  9.75e-02     3s
#    9   5.67132292e+02 -3.28274766e+03  1.41e+01 2.18e-04  3.38e-02     3s
#   10   3.86016255e+02 -1.52975698e+03  7.09e+00 1.28e-04  1.64e-02     3s
#   11   2.33971163e+02 -9.06152486e+02  2.28e+00 8.32e-05  9.52e-03     3s
#   12   1.93882079e+02 -5.72936668e+02  1.34e+00 5.26e-05  6.37e-03     3s
#   13   1.18906647e+02 -1.47077959e+02  1.60e-01 5.66e-05  2.19e-03     3s
#   14   8.04030991e+01 -2.36141531e+00  5.88e-02 1.90e-05  6.81e-04     3s
#   15   6.58583551e+01  1.47816953e+01  2.01e-03 1.25e-05  4.20e-04     3s
#   16   6.13476338e+01  2.19176711e+01  1.46e-03 9.89e-06  3.24e-04     4s
#   17   5.97513275e+01  2.81713661e+01  1.28e-03 7.55e-06  2.59e-04     4s
#   18   5.68021660e+01  3.38022526e+01  9.26e-04 5.43e-06  1.89e-04     4s
#   19   5.32608066e+01  3.97817435e+01  5.14e-04 2.96e-06  1.11e-04     4s
#   20   5.03717194e+01  4.33493934e+01  1.85e-04 1.67e-06  5.76e-05     4s
#   21   4.94363803e+01  4.47488483e+01  9.93e-05 1.10e-06  3.85e-05     4s
#   22   4.88248612e+01  4.55888275e+01  4.95e-05 8.13e-07  2.66e-05     4s
#   23   4.84598148e+01  4.64448935e+01  2.52e-05 5.03e-07  1.65e-05     4s
#   24   4.82676581e+01  4.68092015e+01  1.53e-05 3.75e-07  1.20e-05     4s
#   25   4.81543172e+01  4.72850570e+01  9.88e-06 2.11e-07  7.13e-06     5s
#   26   4.80402917e+01  4.76717602e+01  4.67e-06 7.85e-08  3.02e-06     5s
#   27   4.79775984e+01  4.78424830e+01  2.17e-06 2.94e-08  1.11e-06     5s
#   28   4.79505414e+01  4.78927246e+01  1.11e-06 1.18e-08  4.75e-07     5s
#   29   4.79390123e+01  4.79005505e+01  6.89e-07 8.62e-09  3.16e-07     5s
#   30   4.79279904e+01  4.79069810e+01  2.98e-07 5.87e-09  1.72e-07     5s
#   31   4.79266778e+01  4.79103444e+01  2.56e-07 4.24e-09  1.34e-07     5s
#   32   4.79202675e+01  4.79158867e+01  3.41e-08 2.96e-09  3.60e-08     5s
#   33   4.79195913e+01  4.79175821e+01  1.55e-08 1.54e-09  1.65e-08     5s
#   34   4.79190918e+01  4.79185895e+01  8.17e-09 4.47e-10  4.12e-09     5s
#   35   4.79190071e+01  4.79188672e+01  4.58e-09 1.19e-10  1.15e-09     6s
#   36   4.79189784e+01  4.79189022e+01  1.57e-09 7.23e-11  6.25e-10     6s
#   37   4.79189691e+01  4.79189289e+01  7.21e-10 3.72e-11  3.29e-10     6s
#   38   4.79189619e+01  4.79189506e+01  5.47e-10 1.12e-11  9.29e-11     6s
#   39   4.79189618e+01  4.79189511e+01  4.37e-08 1.07e-11  8.86e-11     6s
#   40   4.79189618e+01  4.79189511e+01  9.03e-08 1.07e-11  8.85e-11     6s
#   41   4.79189618e+01  4.79189511e+01  1.06e-07 1.07e-11  8.85e-11     6s
#   42   4.79189611e+01  4.79189564e+01  6.78e-08 8.06e-10  3.84e-11     7s
#   43   4.79189611e+01  4.79189565e+01  9.08e-08 2.64e-09  3.81e-11     7s
#   44   4.79189602e+01  4.79189592e+01  2.11e-08 1.08e-09  8.19e-12     7s
#   45   4.79189602e+01  4.79189593e+01  4.28e-08 3.76e-08  8.16e-12     7s
#   46   4.79189602e+01  4.79189624e+01  4.28e-08 7.24e-07  8.16e-12     7s
#   47   4.79189602e+01  4.79189637e+01  4.29e-08 1.53e-06  8.16e-12     7s
#   48   4.79189602e+01  4.79189807e+01  4.30e-08 3.17e-06  8.16e-12     7s
#
# Barrier solved model in 48 iterations and 7.46 seconds
# Optimal objective 4.79189619e+01
#
#
# Root crossover log...
#
#     2370 DPushes remaining with DInf 0.0000000e+00                 8s
#        0 DPushes remaining with DInf 0.0000000e+00                 8s
#
#    12885 PPushes remaining with PInf 1.3549164e-02                 8s
#        0 PPushes remaining with PInf 1.5636844e-05                 8s
#
#   Push phase complete: Pinf 1.5636844e-05, Dinf 3.6624414e+01      8s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    14681    4.7918960e+01   0.000000e+00   3.645683e+01      8s
#    15928    4.7918960e+01   0.000000e+00   0.000000e+00      9s
#    15928    4.7918960e+01   0.000000e+00   0.000000e+00      9s
#
# Root relaxation: objective 4.791896e+01, 15928 iterations, 8.29 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   47.91896    0   11          -   47.91896      -     -    9s
# H    0     0                      48.0025422   47.91896  0.17%     -   13s
# H    0     0                      48.0005924   47.91896  0.17%     -   13s
#      0     0   47.94794    0   14   48.00059   47.94794  0.11%     -   64s
#
# Explored 1 nodes (65614 simplex iterations) in 464.14 seconds
# Thread count was 3 (of 8 available processors)
#
# Solution count 1: 48.0006
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (2.2409e-06) exceeds tolerance
# Best objective 4.800059239917e+01, best bound 4.800059239917e+01, gap 0.0000%
#
# Status: ok
# Return code: 0
# Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Termination condition: optimal
# Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# Wall time: 464.1391944885254
# Error rc: 0
# Time: 465.1552608013153
#
#
# Name: x96946
# Lower bound: 48.000592399173
# Upper bound: 48.000592399173
# Number of objectives: 1
# Number of constraints: 85942
# Number of variables: 55618
# Number of binary variables: 52
# Number of integer variables: 52
# Number of continuous variables: 55566
# Number of nonzeros: 264787
# Sense: minimize
#
# Solve time: 470.4149742126465 sec.
#
# Processing optimization output...
# for SourceSinkModel ...    (0.3960sec)
# for ConversionModel ...    (0.3675sec)
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\storage.py:1170: UserWarning:Charge and discharge at the same time for component Li-ion batteries
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\storage.py:1170: UserWarning:Charge and discharge at the same time for component Pumped hydro storage
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\storage.py:1170: UserWarning:Charge and discharge at the same time for component Salt caverns (biogas)
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\storage.py:1170: UserWarning:Charge and discharge at the same time for component Salt caverns (hydrogen)
# for StorageModel ...       (1.0980sec)
# for TransmissionModel ...  (0.8354sec)
# 		(2.7129 sec)

# %% [markdown]
# # Create output file
# Creates for a specific `CO2_reductionTarget` an output file in folder `./results`.

# %%
df1 = esM.getOptimizationSummary("SourceSinkModel", outputLevel=2)
df2 = esM.getOptimizationSummary("ConversionModel", outputLevel=2)
df3 = esM.getOptimizationSummary("StorageModel", outputLevel=2)
df4 = esM.getOptimizationSummary("TransmissionModel", outputLevel=2).loc['Pipelines (hydrogen)']

# Create a Pandas Excel writer using XlsxWriter as the engine.
if not os.path.exists("./results"):
    os.mkdir("./results")
filename = "./results/CO2_reduction_{}_percent.xlsx".format(int(CO2_reductionTarget * 100))
writer = pd.ExcelWriter(filename, engine='xlsxwriter')

# Write each dataframe to a different worksheet.
df1.to_excel(writer, sheet_name='Sources and Sink')
df2.to_excel(writer, sheet_name='Conversion')
df3.to_excel(writer, sheet_name='Storage')
df4.to_excel(writer, sheet_name='Transmission')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# # 9. Selected results output
#
# Plot locations (GeoPandas required)

# %%
# Import the geopandas package for plotting the locations
import geopandas as gpd
import os

def save_figure(fig, file_name):
    folder = "./images/"
    if not os.path.exists(folder):
        os.makedirs(folder)
    fig.savefig(folder + file_name + f"_{CO2_reductionTarget}.png", dpi=900)

# %%
locFilePath = os.path.join(cwd, 'InputData', 'SpatialData','ShapeFiles', 'clusteredRegions.shp')
fig, ax = fn.plotLocations(locFilePath, plotLocNames=True, indexColumn='index')
save_figure(fig, 'Locations')
# Out:
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\IOManagement\standardIO.py:693: MatplotlibDeprecationWarning:The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\IOManagement\standardIO.py:693: MatplotlibDeprecationWarning:The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\IOManagement\standardIO.py:693: MatplotlibDeprecationWarning:The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\IOManagement\standardIO.py:693: MatplotlibDeprecationWarning:The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\IOManagement\standardIO.py:693: MatplotlibDeprecationWarning:The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\IOManagement\standardIO.py:693: MatplotlibDeprecationWarning:The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\IOManagement\standardIO.py:693: MatplotlibDeprecationWarning:The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#  C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\IOManagement\standardIO.py:693: MatplotlibDeprecationWarning:The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.

# %% [markdown]
# ### Sources and Sink
#
# Show optimization summary

# %%
esM.getOptimizationSummary("SourceSinkModel", outputLevel=2)
# Out:
#                                                                       cluster_0  \
# Component                    Property    Unit
# Biogas purchase              TAC         [1e9 Euro/a]                  0.264223
#                              commodCosts [1e9 Euro/a]                  0.264223
#                              operation   [GW$_{biogas,LHV}$*h/a]    4884.879301
#                                          [GW$_{biogas,LHV}$*h]      4884.879301
# CO2 to enviroment            operation   [Mio. t$_{CO_2}$/h*h/a]       2.760762
#                                          [Mio. t$_{CO_2}$/h*h]         2.760762
# Electricity demand           operation   [GW$_{el}$*h/a]          133963.451433
#                                          [GW$_{el}$*h]            133963.451433
# Existing run-of-river plants TAC         [1e9 Euro/a]                  0.144316
#                              capacity    [GW$_{el}$]                   0.693828
#                              operation   [GW$_{el}$*h/a]            3167.329183
#                                          [GW$_{el}$*h]              3167.329183
#                              opexCap     [1e9 Euro/a]                  0.144316
# Hydrogen demand              operation   [GW$_{H_{2},LHV}$*h/a]    15855.229091
#                                          [GW$_{H_{2},LHV}$*h]      15855.229091
# Natural gas purchase         TAC         [1e9 Euro/a]                  0.454633
#                              commodCosts [1e9 Euro/a]                  0.454633
#                              operation   [GW$_{CH_{4},LHV}$*h/a]   13735.134742
#                                          [GW$_{CH_{4},LHV}$*h]     13735.134742
# PV                           TAC         [1e9 Euro/a]                       0.0
#                              capacity    [GW$_{el}$]                        0.0
#                              capexCap    [1e9 Euro/a]                       0.0
#                              invest      [1e9 Euro]                         0.0
#                              operation   [GW$_{el}$*h/a]                    0.0
#                                          [GW$_{el}$*h]                      0.0
#                              opexCap     [1e9 Euro/a]                       0.0
# Wind (offshore)              TAC         [1e9 Euro/a]                       0.0
#                              capacity    [GW$_{el}$]                        NaN
#                              capexCap    [1e9 Euro/a]                       NaN
#                              invest      [1e9 Euro]                         NaN
#                              operation   [GW$_{el}$*h/a]                    NaN
#                                          [GW$_{el}$*h]                      NaN
#                              opexCap     [1e9 Euro/a]                       NaN
# Wind (onshore)               TAC         [1e9 Euro/a]                       0.0
#                              capacity    [GW$_{el}$]                        0.0
#                              capexCap    [1e9 Euro/a]                       0.0
#                              invest      [1e9 Euro]                         0.0
#                              operation   [GW$_{el}$*h/a]                    0.0
#                                          [GW$_{el}$*h]                      0.0
#                              opexCap     [1e9 Euro/a]                       0.0
#
#                                                                      cluster_1  \
# Component                    Property    Unit
# Biogas purchase              TAC         [1e9 Euro/a]                 0.253751
#                              commodCosts [1e9 Euro/a]                 0.253751
#                              operation   [GW$_{biogas,LHV}$*h/a]   4691.281527
#                                          [GW$_{biogas,LHV}$*h]     4691.281527
# CO2 to enviroment            operation   [Mio. t$_{CO_2}$/h*h/a]      2.112631
#                                          [Mio. t$_{CO_2}$/h*h]        2.112631
# Electricity demand           operation   [GW$_{el}$*h/a]          66115.987455
#                                          [GW$_{el}$*h]            66115.987455
# Existing run-of-river plants TAC         [1e9 Euro/a]                 0.007791
#                              capacity    [GW$_{el}$]                  0.037456
#                              operation   [GW$_{el}$*h/a]            170.988002
#                                          [GW$_{el}$*h]              170.988002
#                              opexCap     [1e9 Euro/a]                 0.007791
# Hydrogen demand              operation   [GW$_{H_{2},LHV}$*h/a]   11007.056882
#                                          [GW$_{H_{2},LHV}$*h]     11007.056882
# Natural gas purchase         TAC         [1e9 Euro/a]                 0.347901
#                              commodCosts [1e9 Euro/a]                 0.347901
#                              operation   [GW$_{CH_{4},LHV}$*h/a]  10510.600615
#                                          [GW$_{CH_{4},LHV}$*h]    10510.600615
# PV                           TAC         [1e9 Euro/a]                 1.909967
#                              capacity    [GW$_{el}$]                 25.848365
#                              capexCap    [1e9 Euro/a]                 1.573938
#                              invest      [1e9 Euro]                  16.801437
#                              operation   [GW$_{el}$*h/a]          27233.305162
#                                          [GW$_{el}$*h]            27233.305162
#                              opexCap     [1e9 Euro/a]                 0.336029
# Wind (offshore)              TAC         [1e9 Euro/a]                  1.12104
#                              capacity    [GW$_{el}$]                       4.0
#                              capexCap    [1e9 Euro/a]                  0.93704
#                              invest      [1e9 Euro]                        9.2
#                              operation   [GW$_{el}$*h/a]          15693.822793
#                                          [GW$_{el}$*h]            15693.822793
#                              opexCap     [1e9 Euro/a]                    0.184
# Wind (onshore)               TAC         [1e9 Euro/a]                      0.0
#                              capacity    [GW$_{el}$]                       0.0
#                              capexCap    [1e9 Euro/a]                      0.0
#                              invest      [1e9 Euro]                        0.0
#                              operation   [GW$_{el}$*h/a]                   0.0
#                                          [GW$_{el}$*h]                     0.0
#                              opexCap     [1e9 Euro/a]                      0.0
#
#                                                                       cluster_2  \
# Component                    Property    Unit
# Biogas purchase              TAC         [1e9 Euro/a]                  0.176749
#                              commodCosts [1e9 Euro/a]                  0.176749
#                              operation   [GW$_{biogas,LHV}$*h/a]    3267.674758
#                                          [GW$_{biogas,LHV}$*h]      3267.674758
# CO2 to enviroment            operation   [Mio. t$_{CO_2}$/h*h/a]       2.711247
#                                          [Mio. t$_{CO_2}$/h*h]         2.711247
# Electricity demand           operation   [GW$_{el}$*h/a]          124796.759468
#                                          [GW$_{el}$*h]            124796.759468
# Existing run-of-river plants TAC         [1e9 Euro/a]                   0.00795
#                              capacity    [GW$_{el}$]                   0.038221
#                              operation   [GW$_{el}$*h/a]             174.477553
#                                          [GW$_{el}$*h]               174.477553
#                              opexCap     [1e9 Euro/a]                   0.00795
# Hydrogen demand              operation   [GW$_{H_{2},LHV}$*h/a]    16452.594944
#                                          [GW$_{H_{2},LHV}$*h]      16452.594944
# Natural gas purchase         TAC         [1e9 Euro/a]                  0.446479
#                              commodCosts [1e9 Euro/a]                  0.446479
#                              operation   [GW$_{CH_{4},LHV}$*h/a]   13488.788632
#                                          [GW$_{CH_{4},LHV}$*h]     13488.788632
# PV                           TAC         [1e9 Euro/a]                  2.491089
#                              capacity    [GW$_{el}$]                  33.712925
#                              capexCap    [1e9 Euro/a]                  2.052821
#                              invest      [1e9 Euro]                   21.913401
#                              operation   [GW$_{el}$*h/a]           35668.449676
#                                          [GW$_{el}$*h]             35668.449676
#                              opexCap     [1e9 Euro/a]                  0.438268
# Wind (offshore)              TAC         [1e9 Euro/a]                 14.853784
#                              capacity    [GW$_{el}$]                       53.0
#                              capexCap    [1e9 Euro/a]                 12.415784
#                              invest      [1e9 Euro]                       121.9
#                              operation   [GW$_{el}$*h/a]          219226.824427
#                                          [GW$_{el}$*h]            219226.824427
#                              opexCap     [1e9 Euro/a]                     2.438
# Wind (onshore)               TAC         [1e9 Euro/a]                       0.0
#                              capacity    [GW$_{el}$]                        0.0
#                              capexCap    [1e9 Euro/a]                       0.0
#                              invest      [1e9 Euro]                         0.0
#                              operation   [GW$_{el}$*h/a]                    0.0
#                                          [GW$_{el}$*h]                      0.0
#                              opexCap     [1e9 Euro/a]                       0.0
#
#                                                                      cluster_3  \
# Component                    Property    Unit
# Biogas purchase              TAC         [1e9 Euro/a]                 0.244162
#                              commodCosts [1e9 Euro/a]                 0.244162
#                              operation   [GW$_{biogas,LHV}$*h/a]    4513.99949
#                                          [GW$_{biogas,LHV}$*h]      4513.99949
# CO2 to enviroment            operation   [Mio. t$_{CO_2}$/h*h/a]      1.683093
#                                          [Mio. t$_{CO_2}$/h*h]        1.683093
# Electricity demand           operation   [GW$_{el}$*h/a]          40441.203266
#                                          [GW$_{el}$*h]            40441.203266
# Existing run-of-river plants TAC         [1e9 Euro/a]                 0.009063
#                              capacity    [GW$_{el}$]                  0.043572
#                              operation   [GW$_{el}$*h/a]             198.90441
#                                          [GW$_{el}$*h]               198.90441
#                              opexCap     [1e9 Euro/a]                 0.009063
# Hydrogen demand              operation   [GW$_{H_{2},LHV}$*h/a]    5264.131864
#                                          [GW$_{H_{2},LHV}$*h]      5264.131864
# Natural gas purchase         TAC         [1e9 Euro/a]                 0.277166
#                              commodCosts [1e9 Euro/a]                 0.277166
#                              operation   [GW$_{CH_{4},LHV}$*h/a]   8373.595907
#                                          [GW$_{CH_{4},LHV}$*h]     8373.595907
# PV                           TAC         [1e9 Euro/a]                 1.449702
#                              capacity    [GW$_{el}$]                 19.619408
#                              capexCap    [1e9 Euro/a]                 1.194649
#                              invest      [1e9 Euro]                  12.752615
#                              operation   [GW$_{el}$*h/a]          21186.454177
#                                          [GW$_{el}$*h]            21186.454177
#                              opexCap     [1e9 Euro/a]                 0.255052
# Wind (offshore)              TAC         [1e9 Euro/a]                  1.68156
#                              capacity    [GW$_{el}$]                       6.0
#                              capexCap    [1e9 Euro/a]                  1.40556
#                              invest      [1e9 Euro]                       13.8
#                              operation   [GW$_{el}$*h/a]          21299.332507
#                                          [GW$_{el}$*h]            21299.332507
#                              opexCap     [1e9 Euro/a]                    0.276
# Wind (onshore)               TAC         [1e9 Euro/a]                      0.0
#                              capacity    [GW$_{el}$]                       0.0
#                              capexCap    [1e9 Euro/a]                      0.0
#                              invest      [1e9 Euro]                        0.0
#                              operation   [GW$_{el}$*h/a]                   0.0
#                                          [GW$_{el}$*h]                     0.0
#                              opexCap     [1e9 Euro/a]                      0.0
#
#                                                                      cluster_4  \
# Component                    Property    Unit
# Biogas purchase              TAC         [1e9 Euro/a]                 0.351453
#                              commodCosts [1e9 Euro/a]                 0.351453
#                              operation   [GW$_{biogas,LHV}$*h/a]   6497.551112
#                                          [GW$_{biogas,LHV}$*h]     6497.551112
# CO2 to enviroment            operation   [Mio. t$_{CO_2}$/h*h/a]      3.780703
#                                          [Mio. t$_{CO_2}$/h*h]        3.780703
# Electricity demand           operation   [GW$_{el}$*h/a]          77229.281165
#                                          [GW$_{el}$*h]            77229.281165
# Existing run-of-river plants TAC         [1e9 Euro/a]                 0.556096
#                              capacity    [GW$_{el}$]                  2.673537
#                              operation   [GW$_{el}$*h/a]          12204.710271
#                                          [GW$_{el}$*h]            12204.710271
#                              opexCap     [1e9 Euro/a]                 0.556096
# Hydrogen demand              operation   [GW$_{H_{2},LHV}$*h/a]   10078.267525
#                                          [GW$_{H_{2},LHV}$*h]     10078.267525
# Natural gas purchase         TAC         [1e9 Euro/a]                 0.622593
#                              commodCosts [1e9 Euro/a]                 0.622593
#                              operation   [GW$_{CH_{4},LHV}$*h/a]  18809.467685
#                                          [GW$_{CH_{4},LHV}$*h]    18809.467685
# PV                           TAC         [1e9 Euro/a]                  0.68624
#                              capacity    [GW$_{el}$]                  9.287161
#                              capexCap    [1e9 Euro/a]                 0.565506
#                              invest      [1e9 Euro]                   6.036655
#                              operation   [GW$_{el}$*h/a]          10574.050302
#                                          [GW$_{el}$*h]            10574.050302
#                              opexCap     [1e9 Euro/a]                 0.120733
# Wind (offshore)              TAC         [1e9 Euro/a]                      0.0
#                              capacity    [GW$_{el}$]                       NaN
#                              capexCap    [1e9 Euro/a]                      NaN
#                              invest      [1e9 Euro]                        NaN
#                              operation   [GW$_{el}$*h/a]                   NaN
#                                          [GW$_{el}$*h]                     NaN
#                              opexCap     [1e9 Euro/a]                      NaN
# Wind (onshore)               TAC         [1e9 Euro/a]                      0.0
#                              capacity    [GW$_{el}$]                       0.0
#                              capexCap    [1e9 Euro/a]                      0.0
#                              invest      [1e9 Euro]                        0.0
#                              operation   [GW$_{el}$*h/a]                   0.0
#                                          [GW$_{el}$*h]                     0.0
#                              opexCap     [1e9 Euro/a]                      0.0
#
#                                                                      cluster_5  \
# Component                    Property    Unit
# Biogas purchase              TAC         [1e9 Euro/a]                 0.155594
#                              commodCosts [1e9 Euro/a]                 0.155594
#                              operation   [GW$_{biogas,LHV}$*h/a]   2876.580098
#                                          [GW$_{biogas,LHV}$*h]     2876.580098
# CO2 to enviroment            operation   [Mio. t$_{CO_2}$/h*h/a]      2.377975
#                                          [Mio. t$_{CO_2}$/h*h]        2.377975
# Electricity demand           operation   [GW$_{el}$*h/a]          41413.409155
#                                          [GW$_{el}$*h]            41413.409155
# Existing run-of-river plants TAC         [1e9 Euro/a]                      0.0
#                              capacity    [GW$_{el}$]                       NaN
#                              operation   [GW$_{el}$*h/a]                   NaN
#                                          [GW$_{el}$*h]                     NaN
#                              opexCap     [1e9 Euro/a]                      NaN
# Hydrogen demand              operation   [GW$_{H_{2},LHV}$*h/a]    5747.423572
#                                          [GW$_{H_{2},LHV}$*h]      5747.423572
# Natural gas purchase         TAC         [1e9 Euro/a]                 0.391597
#                              commodCosts [1e9 Euro/a]                 0.391597
#                              operation   [GW$_{CH_{4},LHV}$*h/a]  11830.721464
#                                          [GW$_{CH_{4},LHV}$*h]    11830.721464
# PV                           TAC         [1e9 Euro/a]                 1.469767
#                              capacity    [GW$_{el}$]                 19.890954
#                              capexCap    [1e9 Euro/a]                 1.211184
#                              invest      [1e9 Euro]                   12.92912
#                              operation   [GW$_{el}$*h/a]          20813.876827
#                                          [GW$_{el}$*h]            20813.876827
#                              opexCap     [1e9 Euro/a]                 0.258582
# Wind (offshore)              TAC         [1e9 Euro/a]                      0.0
#                              capacity    [GW$_{el}$]                       NaN
#                              capexCap    [1e9 Euro/a]                      NaN
#                              invest      [1e9 Euro]                        NaN
#                              operation   [GW$_{el}$*h/a]                   NaN
#                                          [GW$_{el}$*h]                     NaN
#                              opexCap     [1e9 Euro/a]                      NaN
# Wind (onshore)               TAC         [1e9 Euro/a]                      0.0
#                              capacity    [GW$_{el}$]                       0.0
#                              capexCap    [1e9 Euro/a]                      0.0
#                              invest      [1e9 Euro]                        0.0
#                              operation   [GW$_{el}$*h/a]                   0.0
#                                          [GW$_{el}$*h]                     0.0
#                              opexCap     [1e9 Euro/a]                      0.0
#
#                                                                      cluster_6  \
# Component                    Property    Unit
# Biogas purchase              TAC         [1e9 Euro/a]                 0.164873
#                              commodCosts [1e9 Euro/a]                 0.164873
#                              operation   [GW$_{biogas,LHV}$*h/a]    3048.12582
#                                          [GW$_{biogas,LHV}$*h]      3048.12582
# CO2 to enviroment            operation   [Mio. t$_{CO_2}$/h*h/a]      0.634607
#                                          [Mio. t$_{CO_2}$/h*h]        0.634607
# Electricity demand           operation   [GW$_{el}$*h/a]          28088.766223
#                                          [GW$_{el}$*h]            28088.766223
# Existing run-of-river plants TAC         [1e9 Euro/a]                      0.0
#                              capacity    [GW$_{el}$]                       NaN
#                              operation   [GW$_{el}$*h/a]                   NaN
#                                          [GW$_{el}$*h]                     NaN
#                              opexCap     [1e9 Euro/a]                      NaN
# Hydrogen demand              operation   [GW$_{H_{2},LHV}$*h/a]    3710.050514
#                                          [GW$_{H_{2},LHV}$*h]      3710.050514
# Natural gas purchase         TAC         [1e9 Euro/a]                 0.104505
#                              commodCosts [1e9 Euro/a]                 0.104505
#                              operation   [GW$_{CH_{4},LHV}$*h/a]   3157.249464
#                                          [GW$_{CH_{4},LHV}$*h]     3157.249464
# PV                           TAC         [1e9 Euro/a]                 0.933703
#                              capacity    [GW$_{el}$]                 12.636188
#                              capexCap    [1e9 Euro/a]                 0.769433
#                              invest      [1e9 Euro]                   8.213522
#                              operation   [GW$_{el}$*h/a]          13518.741616
#                                          [GW$_{el}$*h]            13518.741616
#                              opexCap     [1e9 Euro/a]                  0.16427
# Wind (offshore)              TAC         [1e9 Euro/a]                 5.044681
#                              capacity    [GW$_{el}$]                      18.0
#                              capexCap    [1e9 Euro/a]                 4.216681
#                              invest      [1e9 Euro]                       41.4
#                              operation   [GW$_{el}$*h/a]          82971.151135
#                                          [GW$_{el}$*h]            82971.151135
#                              opexCap     [1e9 Euro/a]                    0.828
# Wind (onshore)               TAC         [1e9 Euro/a]                 4.102413
#                              capacity    [GW$_{el}$]                 30.606471
#                              capexCap    [1e9 Euro/a]                  3.42907
#                              invest      [1e9 Euro]                  33.667118
#                              operation   [GW$_{el}$*h/a]          73685.635261
#                                          [GW$_{el}$*h]            73685.635261
#                              opexCap     [1e9 Euro/a]                 0.673342
#
#                                                                      cluster_7
# Component                    Property    Unit
# Biogas purchase              TAC         [1e9 Euro/a]                 0.065985
#                              commodCosts [1e9 Euro/a]                 0.065985
#                              operation   [GW$_{biogas,LHV}$*h/a]   1219.907894
#                                          [GW$_{biogas,LHV}$*h]     1219.907894
# CO2 to enviroment            operation   [Mio. t$_{CO_2}$/h*h/a]      2.238983
#                                          [Mio. t$_{CO_2}$/h*h]        2.238983
# Electricity demand           operation   [GW$_{el}$*h/a]          15851.141245
#                                          [GW$_{el}$*h]            15851.141245
# Existing run-of-river plants TAC         [1e9 Euro/a]                 0.067472
#                              capacity    [GW$_{el}$]                  0.324386
#                              operation   [GW$_{el}$*h/a]           1480.823705
#                                          [GW$_{el}$*h]             1480.823705
#                              opexCap     [1e9 Euro/a]                 0.067472
# Hydrogen demand              operation   [GW$_{H_{2},LHV}$*h/a]    1453.124166
#                                          [GW$_{H_{2},LHV}$*h]      1453.124166
# Natural gas purchase         TAC         [1e9 Euro/a]                 0.368708
#                              commodCosts [1e9 Euro/a]                 0.368708
#                              operation   [GW$_{CH_{4},LHV}$*h/a]   11139.21761
#                                          [GW$_{CH_{4},LHV}$*h]     11139.21761
# PV                           TAC         [1e9 Euro/a]                      0.0
#                              capacity    [GW$_{el}$]                       0.0
#                              capexCap    [1e9 Euro/a]                      0.0
#                              invest      [1e9 Euro]                        0.0
#                              operation   [GW$_{el}$*h/a]                   0.0
#                                          [GW$_{el}$*h]                     0.0
#                              opexCap     [1e9 Euro/a]                      0.0
# Wind (offshore)              TAC         [1e9 Euro/a]                      0.0
#                              capacity    [GW$_{el}$]                       NaN
#                              capexCap    [1e9 Euro/a]                      NaN
#                              invest      [1e9 Euro]                        NaN
#                              operation   [GW$_{el}$*h/a]                   NaN
#                                          [GW$_{el}$*h]                     NaN
#                              opexCap     [1e9 Euro/a]                      NaN
# Wind (onshore)               TAC         [1e9 Euro/a]                      0.0
#                              capacity    [GW$_{el}$]                       0.0
#                              capexCap    [1e9 Euro/a]                      0.0
#                              invest      [1e9 Euro]                        0.0
#                              operation   [GW$_{el}$*h/a]                   0.0
#                                          [GW$_{el}$*h]                     0.0
#                              opexCap     [1e9 Euro/a]                      0.0

# %% [markdown]
# Plot installed capacities

# %%
fig, ax = fn.plotLocationalColorMap(esM, 'Wind (offshore)', locFilePath, 'index', perArea=False)
save_figure(fig, 'Capacity_wind_offshore')

# %%
fig, ax = fn.plotLocationalColorMap(esM, 'Wind (onshore)', locFilePath, 'index', perArea=False)
save_figure(fig, 'Capacity_wind_onshore')

# %%
fig, ax = fn.plotLocationalColorMap(esM, 'PV', locFilePath, 'index', perArea=False)
save_figure(fig, 'Capacity_PV')

# %% [markdown]
# Plot operation time series (either one or two dimensional)

# %%
fig, ax = fn.plotOperation(esM, 'Electricity demand', 'cluster_0')
save_figure(fig, 'Demand_electricity')

# %%
fig, ax = fn.plotOperationColorMap(esM, 'Electricity demand', 'cluster_0')

# %% [markdown]
# ### Conversion
#
# Show optimization summary

# %%
esM.getOptimizationSummary("ConversionModel", outputLevel=2)
# Out:
#                                                       cluster_0    cluster_1  \
# Component                Property  Unit
# CCGT plants (methane)    TAC       [1e9 Euro/a]        0.308056     0.276427
#                          capacity  [GW$_{el}$]         3.977295     3.568936
#                          capexCap  [1e9 Euro/a]        0.224532     0.201479
#                          invest    [1e9 Euro]          2.585242     2.319808
#                          operation [GW$_{el}$*h/a]  8241.080845  6306.360369
#                                    [GW$_{el}$*h]    8241.080845  6306.360369
#                          opexCap   [1e9 Euro/a]        0.083523     0.074948
# Electrolyzer             TAC       [1e9 Euro/a]             0.0          0.0
#                          capacity  [GW$_{el}$]              0.0          0.0
#                          capexCap  [1e9 Euro/a]             0.0          0.0
#                          invest    [1e9 Euro]               0.0          0.0
#                          operation [GW$_{el}$*h/a]          0.0          0.0
#                                    [GW$_{el}$*h]            0.0          0.0
#                          opexCap   [1e9 Euro/a]             0.0          0.0
# New CCGT plants (biogas) TAC       [1e9 Euro/a]        0.078299     0.116117
#                          capacity  [GW$_{el}$]         0.957241     1.419595
#                          capexCap  [1e9 Euro/a]        0.058197     0.086306
#                          invest    [1e9 Euro]          0.670069     0.993716
#                          operation [GW$_{el}$*h/a]  2894.912743  4875.826629
#                                    [GW$_{el}$*h]    2894.912743  4875.826629
#                          opexCap   [1e9 Euro/a]        0.020102     0.029811
#
#                                                       cluster_2    cluster_3  \
# Component                Property  Unit
# CCGT plants (methane)    TAC       [1e9 Euro/a]        0.234338     0.200083
#                          capacity  [GW$_{el}$]         3.025523     2.583262
#                          capexCap  [1e9 Euro/a]        0.170802     0.145834
#                          invest    [1e9 Euro]           1.96659      1.67912
#                          operation [GW$_{el}$*h/a]  8093.273179  5024.157544
#                                    [GW$_{el}$*h]    8093.273179  5024.157544
#                          opexCap   [1e9 Euro/a]        0.063536     0.054248
# Electrolyzer             TAC       [1e9 Euro/a]        0.389147          0.0
#                          capacity  [GW$_{el}$]         4.472194          0.0
#                          capexCap  [1e9 Euro/a]        0.333244          0.0
#                          invest    [1e9 Euro]          2.236097          0.0
#                          operation [GW$_{el}$*h/a]   18409.2889          0.0
#                                    [GW$_{el}$*h]     18409.2889          0.0
#                          opexCap   [1e9 Euro/a]        0.055902          0.0
# New CCGT plants (biogas) TAC       [1e9 Euro/a]        0.106627     0.066066
#                          capacity  [GW$_{el}$]         1.303576     0.807689
#                          capexCap  [1e9 Euro/a]        0.079252     0.049104
#                          invest    [1e9 Euro]          0.912503     0.565382
#                          operation [GW$_{el}$*h/a]  4443.457811  2843.819679
#                                    [GW$_{el}$*h]    4443.457811  2843.819679
#                          opexCap   [1e9 Euro/a]        0.027375     0.016961
#
#                                                        cluster_4    cluster_5  \
# Component                Property  Unit
# CCGT plants (methane)    TAC       [1e9 Euro/a]         0.289931     0.234701
#                          capacity  [GW$_{el}$]          3.743294     3.030218
#                          capexCap  [1e9 Euro/a]         0.211322     0.171067
#                          invest    [1e9 Euro]           2.433141     1.969642
#                          operation [GW$_{el}$*h/a]  11285.680611  7098.432879
#                                    [GW$_{el}$*h]    11285.680611  7098.432879
#                          opexCap   [1e9 Euro/a]         0.078609     0.063635
# Electrolyzer             TAC       [1e9 Euro/a]              0.0          0.0
#                          capacity  [GW$_{el}$]               0.0          0.0
#                          capexCap  [1e9 Euro/a]              0.0          0.0
#                          invest    [1e9 Euro]                0.0          0.0
#                          operation [GW$_{el}$*h/a]           0.0          0.0
#                                    [GW$_{el}$*h]             0.0          0.0
#                          opexCap   [1e9 Euro/a]              0.0          0.0
# New CCGT plants (biogas) TAC       [1e9 Euro/a]         0.038222     0.042279
#                          capacity  [GW$_{el}$]           0.46729     0.516884
#                          capexCap  [1e9 Euro/a]         0.028409     0.031425
#                          invest    [1e9 Euro]           0.327103     0.361818
#                          operation [GW$_{el}$*h/a]   2011.214588  1812.245462
#                                    [GW$_{el}$*h]     2011.214588  1812.245462
#                          opexCap   [1e9 Euro/a]         0.009813     0.010855
#
#                                                        cluster_6    cluster_7
# Component                Property  Unit
# CCGT plants (methane)    TAC       [1e9 Euro/a]         0.135488     0.202701
#                          capacity  [GW$_{el}$]           1.74928      2.61706
#                          capexCap  [1e9 Euro/a]         0.098753     0.147742
#                          invest    [1e9 Euro]           1.137032     1.701089
#                          operation [GW$_{el}$*h/a]   1894.349678  6683.530566
#                                    [GW$_{el}$*h]     1894.349678  6683.530566
#                          opexCap   [1e9 Euro/a]         0.036735     0.054958
# Electrolyzer             TAC       [1e9 Euro/a]         1.585227          0.0
#                          capacity  [GW$_{el}$]         18.217916          0.0
#                          capexCap  [1e9 Euro/a]         1.357503          0.0
#                          invest    [1e9 Euro]           9.108958          0.0
#                          operation [GW$_{el}$*h/a]  80973.394756          0.0
#                                    [GW$_{el}$*h]    80973.394756          0.0
#                          opexCap   [1e9 Euro/a]         0.227724          0.0
# New CCGT plants (biogas) TAC       [1e9 Euro/a]              0.0     0.014352
#                          capacity  [GW$_{el}$]               0.0     0.175466
#                          capexCap  [1e9 Euro/a]              0.0     0.010668
#                          invest    [1e9 Euro]                0.0     0.122826
#                          operation [GW$_{el}$*h/a]           0.0    648.52309
#                                    [GW$_{el}$*h]             0.0    648.52309
#                          opexCap   [1e9 Euro/a]              0.0     0.003685

# %%
fig, ax = fn.plotLocationalColorMap(esM, 'Electrolyzer', locFilePath, 'index', perArea=False, zlabel='Installed capacity\nin GW\n')

# %%
fig, ax = fn.plotOperationColorMap(esM, 'New CCGT plants (biogas)', 'cluster_2')

# %% [markdown]
# ### Storage
#
# Show optimization summary

# %%
esM.getOptimizationSummary("StorageModel", outputLevel=2)
# Out:
#                                                                       cluster_0  \
# Component               Property           Unit
# Li-ion batteries        TAC                [1e9 Euro/a]                     0.0
#                         capacity           [GW$_{el}$*h]                    0.0
#                         capexCap           [1e9 Euro/a]                     0.0
#                         invest             [1e9 Euro]                       0.0
#                         operationCharge    [GW$_{el}$*h/a]                  0.0
#                                            [GW$_{el}$*h]                    0.0
#                         operationDischarge [GW$_{el}$*h/a]                  0.0
#                                            [GW$_{el}$*h]                    0.0
#                         opexCap            [1e9 Euro/a]                     0.0
# Pumped hydro storage    TAC                [1e9 Euro/a]                0.002436
#                         capacity           [GW$_{el}$*h]                 15.924
#                         operationCharge    [GW$_{el}$*h/a]           5477.69714
#                                            [GW$_{el}$*h]             5477.69714
#                         operationDischarge [GW$_{el}$*h/a]          4241.678855
#                                            [GW$_{el}$*h]            4241.678855
#                         opexCap            [1e9 Euro/a]                0.002436
# Salt caverns (biogas)   TAC                [1e9 Euro/a]                     0.0
#                         capacity           [GW$_{biogas,LHV}$*h]            NaN
#                         capexCap           [1e9 Euro/a]                     NaN
#                         invest             [1e9 Euro]                       NaN
#                         operationCharge    [GW$_{biogas,LHV}$*h/a]          NaN
#                                            [GW$_{biogas,LHV}$*h]            NaN
#                         operationDischarge [GW$_{biogas,LHV}$*h/a]          NaN
#                                            [GW$_{biogas,LHV}$*h]            NaN
#                         opexCap            [1e9 Euro/a]                     NaN
# Salt caverns (hydrogen) TAC                [1e9 Euro/a]                     0.0
#                         capacity           [GW$_{H_{2},LHV}$*h]             NaN
#                         capexCap           [1e9 Euro/a]                     NaN
#                         invest             [1e9 Euro]                       NaN
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]           NaN
#                                            [GW$_{H_{2},LHV}$*h]             NaN
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]           NaN
#                                            [GW$_{H_{2},LHV}$*h]             NaN
#                         opexCap            [1e9 Euro/a]                     NaN
#
#                                                                        cluster_1  \
# Component               Property           Unit
# Li-ion batteries        TAC                [1e9 Euro/a]                      0.0
#                         capacity           [GW$_{el}$*h]                     0.0
#                         capexCap           [1e9 Euro/a]                      0.0
#                         invest             [1e9 Euro]                        0.0
#                         operationCharge    [GW$_{el}$*h/a]                   0.0
#                                            [GW$_{el}$*h]                     0.0
#                         operationDischarge [GW$_{el}$*h/a]                   0.0
#                                            [GW$_{el}$*h]                     0.0
#                         opexCap            [1e9 Euro/a]                      0.0
# Pumped hydro storage    TAC                [1e9 Euro/a]                 0.001186
#                         capacity           [GW$_{el}$*h]                   7.751
#                         operationCharge    [GW$_{el}$*h/a]           3058.271588
#                                            [GW$_{el}$*h]             3058.271588
#                         operationDischarge [GW$_{el}$*h/a]           2368.228108
#                                            [GW$_{el}$*h]             2368.228108
#                         opexCap            [1e9 Euro/a]                 0.001186
# Salt caverns (biogas)   TAC                [1e9 Euro/a]                 0.008733
#                         capacity           [GW$_{biogas,LHV}$*h]      644.327497
#                         capexCap           [1e9 Euro/a]                 0.002289
#                         invest             [1e9 Euro]                   0.025773
#                         operationCharge    [GW$_{biogas,LHV}$*h/a]   4023.563175
#                                            [GW$_{biogas,LHV}$*h]     4023.563175
#                         operationDischarge [GW$_{biogas,LHV}$*h/a]   4023.563175
#                                            [GW$_{biogas,LHV}$*h]     4023.563175
#                         opexCap            [1e9 Euro/a]                 0.006443
# Salt caverns (hydrogen) TAC                [1e9 Euro/a]                 1.034159
#                         capacity           [GW$_{H_{2},LHV}$*h]      1783.736178
#                         capexCap           [1e9 Euro/a]                 0.017429
#                         invest             [1e9 Euro]                   0.196211
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]   13197.122816
#                                            [GW$_{H_{2},LHV}$*h]     13197.122816
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]   13197.122816
#                                            [GW$_{H_{2},LHV}$*h]     13197.122816
#                         opexCap            [1e9 Euro/a]                  1.01673
#
#                                                                       cluster_2  \
# Component               Property           Unit
# Li-ion batteries        TAC                [1e9 Euro/a]                0.034173
#                         capacity           [GW$_{el}$*h]               2.033767
#                         capexCap           [1e9 Euro/a]                0.030106
#                         invest             [1e9 Euro]                  0.307099
#                         operationCharge    [GW$_{el}$*h/a]           650.050008
#                                            [GW$_{el}$*h]             650.050008
#                         operationDischarge [GW$_{el}$*h/a]           586.456364
#                                            [GW$_{el}$*h]             586.456364
#                         opexCap            [1e9 Euro/a]                0.004068
# Pumped hydro storage    TAC                [1e9 Euro/a]                0.000125
#                         capacity           [GW$_{el}$*h]                  0.818
#                         operationCharge    [GW$_{el}$*h/a]           324.034797
#                                            [GW$_{el}$*h]             324.034797
#                         operationDischarge [GW$_{el}$*h/a]           250.922534
#                                            [GW$_{el}$*h]             250.922534
#                         opexCap            [1e9 Euro/a]                0.000125
# Salt caverns (biogas)   TAC                [1e9 Euro/a]                0.017832
#                         capacity           [GW$_{biogas,LHV}$*h]    1315.719124
#                         capexCap           [1e9 Euro/a]                0.004675
#                         invest             [1e9 Euro]                  0.052629
#                         operationCharge    [GW$_{biogas,LHV}$*h/a]  8272.236186
#                                            [GW$_{biogas,LHV}$*h]    8272.236186
#                         operationDischarge [GW$_{biogas,LHV}$*h/a]  8272.236186
#                                            [GW$_{biogas,LHV}$*h]    8272.236186
#                         opexCap            [1e9 Euro/a]                0.013157
# Salt caverns (hydrogen) TAC                [1e9 Euro/a]                0.498945
#                         capacity           [GW$_{H_{2},LHV}$*h]       860.59051
#                         capexCap           [1e9 Euro/a]                0.008409
#                         invest             [1e9 Euro]                  0.094665
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]   6426.900412
#                                            [GW$_{H_{2},LHV}$*h]     6426.900412
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]   6426.900412
#                                            [GW$_{H_{2},LHV}$*h]     6426.900412
#                         opexCap            [1e9 Euro/a]                0.490537
#
#                                                                       cluster_3  \
# Component               Property           Unit
# Li-ion batteries        TAC                [1e9 Euro/a]                     0.0
#                         capacity           [GW$_{el}$*h]                    0.0
#                         capexCap           [1e9 Euro/a]                     0.0
#                         invest             [1e9 Euro]                       0.0
#                         operationCharge    [GW$_{el}$*h/a]                  0.0
#                                            [GW$_{el}$*h]                    0.0
#                         operationDischarge [GW$_{el}$*h/a]                  0.0
#                                            [GW$_{el}$*h]                    0.0
#                         opexCap            [1e9 Euro/a]                     0.0
# Pumped hydro storage    TAC                [1e9 Euro/a]                0.003002
#                         capacity           [GW$_{el}$*h]                  19.62
#                         operationCharge    [GW$_{el}$*h/a]          6260.344098
#                                            [GW$_{el}$*h]            6260.344098
#                         operationDischarge [GW$_{el}$*h/a]          4847.736551
#                                            [GW$_{el}$*h]            4847.736551
#                         opexCap            [1e9 Euro/a]                0.003002
# Salt caverns (biogas)   TAC                [1e9 Euro/a]                0.004888
#                         capacity           [GW$_{biogas,LHV}$*h]      360.65591
#                         capexCap           [1e9 Euro/a]                0.001281
#                         invest             [1e9 Euro]                  0.014426
#                         operationCharge    [GW$_{biogas,LHV}$*h/a]  2469.628247
#                                            [GW$_{biogas,LHV}$*h]    2469.628247
#                         operationDischarge [GW$_{biogas,LHV}$*h/a]  2469.628247
#                                            [GW$_{biogas,LHV}$*h]    2469.628247
#                         opexCap            [1e9 Euro/a]                0.003607
# Salt caverns (hydrogen) TAC                [1e9 Euro/a]                     0.0
#                         capacity           [GW$_{H_{2},LHV}$*h]             0.0
#                         capexCap           [1e9 Euro/a]                     0.0
#                         invest             [1e9 Euro]                       0.0
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]           0.0
#                                            [GW$_{H_{2},LHV}$*h]             0.0
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]           0.0
#                                            [GW$_{H_{2},LHV}$*h]             0.0
#                         opexCap            [1e9 Euro/a]                     0.0
#
#                                                                       cluster_4  \
# Component               Property           Unit
# Li-ion batteries        TAC                [1e9 Euro/a]                     0.0
#                         capacity           [GW$_{el}$*h]                    0.0
#                         capexCap           [1e9 Euro/a]                     0.0
#                         invest             [1e9 Euro]                       0.0
#                         operationCharge    [GW$_{el}$*h/a]                  0.0
#                                            [GW$_{el}$*h]                    0.0
#                         operationDischarge [GW$_{el}$*h/a]                  0.0
#                                            [GW$_{el}$*h]                    0.0
#                         opexCap            [1e9 Euro/a]                     0.0
# Pumped hydro storage    TAC                [1e9 Euro/a]                  0.0011
#                         capacity           [GW$_{el}$*h]                   7.19
#                         operationCharge    [GW$_{el}$*h/a]          2503.144817
#                                            [GW$_{el}$*h]            2503.144817
#                         operationDischarge [GW$_{el}$*h/a]          1938.329058
#                                            [GW$_{el}$*h]            1938.329058
#                         opexCap            [1e9 Euro/a]                  0.0011
# Salt caverns (biogas)   TAC                [1e9 Euro/a]                     0.0
#                         capacity           [GW$_{biogas,LHV}$*h]            NaN
#                         capexCap           [1e9 Euro/a]                     NaN
#                         invest             [1e9 Euro]                       NaN
#                         operationCharge    [GW$_{biogas,LHV}$*h/a]          NaN
#                                            [GW$_{biogas,LHV}$*h]            NaN
#                         operationDischarge [GW$_{biogas,LHV}$*h/a]          NaN
#                                            [GW$_{biogas,LHV}$*h]            NaN
#                         opexCap            [1e9 Euro/a]                     NaN
# Salt caverns (hydrogen) TAC                [1e9 Euro/a]                     0.0
#                         capacity           [GW$_{H_{2},LHV}$*h]             NaN
#                         capexCap           [1e9 Euro/a]                     NaN
#                         invest             [1e9 Euro]                       NaN
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]           NaN
#                                            [GW$_{H_{2},LHV}$*h]             NaN
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]           NaN
#                                            [GW$_{H_{2},LHV}$*h]             NaN
#                         opexCap            [1e9 Euro/a]                     NaN
#
#                                                                       cluster_5  \
# Component               Property           Unit
# Li-ion batteries        TAC                [1e9 Euro/a]                     0.0
#                         capacity           [GW$_{el}$*h]                    0.0
#                         capexCap           [1e9 Euro/a]                     0.0
#                         invest             [1e9 Euro]                       0.0
#                         operationCharge    [GW$_{el}$*h/a]                  0.0
#                                            [GW$_{el}$*h]                    0.0
#                         operationDischarge [GW$_{el}$*h/a]                  0.0
#                                            [GW$_{el}$*h]                    0.0
#                         opexCap            [1e9 Euro/a]                     0.0
# Pumped hydro storage    TAC                [1e9 Euro/a]                 0.00383
#                         capacity           [GW$_{el}$*h]                 25.034
#                         operationCharge    [GW$_{el}$*h/a]          8016.184904
#                                            [GW$_{el}$*h]            8016.184904
#                         operationDischarge [GW$_{el}$*h/a]          6207.402033
#                                            [GW$_{el}$*h]            6207.402033
#                         opexCap            [1e9 Euro/a]                 0.00383
# Salt caverns (biogas)   TAC                [1e9 Euro/a]                0.003137
#                         capacity           [GW$_{biogas,LHV}$*h]     231.456519
#                         capexCap           [1e9 Euro/a]                0.000822
#                         invest             [1e9 Euro]                  0.009258
#                         operationCharge    [GW$_{biogas,LHV}$*h/a]  1547.917576
#                                            [GW$_{biogas,LHV}$*h]    1547.917576
#                         operationDischarge [GW$_{biogas,LHV}$*h/a]  1547.917576
#                                            [GW$_{biogas,LHV}$*h]    1547.917576
#                         opexCap            [1e9 Euro/a]                0.002315
# Salt caverns (hydrogen) TAC                [1e9 Euro/a]                     0.0
#                         capacity           [GW$_{H_{2},LHV}$*h]             0.0
#                         capexCap           [1e9 Euro/a]                     0.0
#                         invest             [1e9 Euro]                       0.0
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]           0.0
#                                            [GW$_{H_{2},LHV}$*h]             0.0
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]           0.0
#                                            [GW$_{H_{2},LHV}$*h]             0.0
#                         opexCap            [1e9 Euro/a]                     0.0
#
#                                                                        cluster_6  \
# Component               Property           Unit
# Li-ion batteries        TAC                [1e9 Euro/a]                 0.040144
#                         capacity           [GW$_{el}$*h]                2.389128
#                         capexCap           [1e9 Euro/a]                 0.035366
#                         invest             [1e9 Euro]                   0.360758
#                         operationCharge    [GW$_{el}$*h/a]            823.428894
#                                            [GW$_{el}$*h]              823.428894
#                         operationDischarge [GW$_{el}$*h/a]            742.965648
#                                            [GW$_{el}$*h]              742.965648
#                         opexCap            [1e9 Euro/a]                 0.004778
# Pumped hydro storage    TAC                [1e9 Euro/a]                 0.000092
#                         capacity           [GW$_{el}$*h]                     0.6
#                         operationCharge    [GW$_{el}$*h/a]            237.755857
#                                            [GW$_{el}$*h]              237.755857
#                         operationDischarge [GW$_{el}$*h/a]            184.108922
#                                            [GW$_{el}$*h]              184.108922
#                         opexCap            [1e9 Euro/a]                 0.000092
# Salt caverns (biogas)   TAC                [1e9 Euro/a]                      0.0
#                         capacity           [GW$_{biogas,LHV}$*h]             0.0
#                         capexCap           [1e9 Euro/a]                      0.0
#                         invest             [1e9 Euro]                        0.0
#                         operationCharge    [GW$_{biogas,LHV}$*h/a]           0.0
#                                            [GW$_{biogas,LHV}$*h]             0.0
#                         operationDischarge [GW$_{biogas,LHV}$*h/a]           0.0
#                                            [GW$_{biogas,LHV}$*h]             0.0
#                         opexCap            [1e9 Euro/a]                      0.0
# Salt caverns (hydrogen) TAC                [1e9 Euro/a]                 0.632608
#                         capacity           [GW$_{H_{2},LHV}$*h]      1091.134846
#                         capexCap           [1e9 Euro/a]                 0.010661
#                         invest             [1e9 Euro]                   0.120025
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]   12540.372693
#                                            [GW$_{H_{2},LHV}$*h]     12540.372693
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]   12540.372693
#                                            [GW$_{H_{2},LHV}$*h]     12540.372693
#                         opexCap            [1e9 Euro/a]                 0.621947
#
#                                                                    cluster_7
# Component               Property           Unit
# Li-ion batteries        TAC                [1e9 Euro/a]                  0.0
#                         capacity           [GW$_{el}$*h]                 0.0
#                         capexCap           [1e9 Euro/a]                  0.0
#                         invest             [1e9 Euro]                    0.0
#                         operationCharge    [GW$_{el}$*h/a]               0.0
#                                            [GW$_{el}$*h]                 0.0
#                         operationDischarge [GW$_{el}$*h/a]               0.0
#                                            [GW$_{el}$*h]                 0.0
#                         opexCap            [1e9 Euro/a]                  0.0
# Pumped hydro storage    TAC                [1e9 Euro/a]                  0.0
#                         capacity           [GW$_{el}$*h]                 NaN
#                         operationCharge    [GW$_{el}$*h/a]               NaN
#                                            [GW$_{el}$*h]                 NaN
#                         operationDischarge [GW$_{el}$*h/a]               NaN
#                                            [GW$_{el}$*h]                 NaN
#                         opexCap            [1e9 Euro/a]                  NaN
# Salt caverns (biogas)   TAC                [1e9 Euro/a]                  0.0
#                         capacity           [GW$_{biogas,LHV}$*h]         NaN
#                         capexCap           [1e9 Euro/a]                  NaN
#                         invest             [1e9 Euro]                    NaN
#                         operationCharge    [GW$_{biogas,LHV}$*h/a]       NaN
#                                            [GW$_{biogas,LHV}$*h]         NaN
#                         operationDischarge [GW$_{biogas,LHV}$*h/a]       NaN
#                                            [GW$_{biogas,LHV}$*h]         NaN
#                         opexCap            [1e9 Euro/a]                  NaN
# Salt caverns (hydrogen) TAC                [1e9 Euro/a]                  0.0
#                         capacity           [GW$_{H_{2},LHV}$*h]          NaN
#                         capexCap           [1e9 Euro/a]                  NaN
#                         invest             [1e9 Euro]                    NaN
#                         operationCharge    [GW$_{H_{2},LHV}$*h/a]        NaN
#                                            [GW$_{H_{2},LHV}$*h]          NaN
#                         operationDischarge [GW$_{H_{2},LHV}$*h/a]        NaN
#                                            [GW$_{H_{2},LHV}$*h]          NaN
#                         opexCap            [1e9 Euro/a]                  NaN

# %%
fig, ax = fn.plotOperationColorMap(esM, 'Li-ion batteries', 'cluster_2', 
                                   variableName='stateOfChargeOperationVariablesOptimum')

# %%
fig, ax = fn.plotOperationColorMap(esM, 'Pumped hydro storage', 'cluster_2',
                                  variableName='stateOfChargeOperationVariablesOptimum')

# %%
fig, ax = fn.plotOperationColorMap(esM, 'Salt caverns (biogas)', 'cluster_2',
                                  variableName='stateOfChargeOperationVariablesOptimum')

# %%
fig, ax = fn.plotOperationColorMap(esM, 'Salt caverns (hydrogen)', 'cluster_2',
                                  variableName='stateOfChargeOperationVariablesOptimum')

# %% [markdown]
# ## Transmission
#
# Show optimization summary

# %%
esM.getOptimizationSummary("TransmissionModel", outputLevel=2).loc['Pipelines (hydrogen)']
# Out:
#                                                    cluster_0    cluster_1  \
# Property     Unit                   LocationIn
# TAC          [1e9 Euro/a]           cluster_0            0.0     0.013705
#                                     cluster_1       0.013705          0.0
#                                     cluster_2            0.0     0.003624
#                                     cluster_3            0.0          0.0
#                                     cluster_4       0.006892          0.0
#                                     cluster_5            0.0          0.0
#                                     cluster_6            0.0     0.024032
#                                     cluster_7       0.002953          0.0
# capacity     [GW$_{H_{2},LHV}$]     cluster_0            NaN     3.126327
#                                     cluster_1       3.126327          NaN
#                                     cluster_2            0.0     0.577217
#                                     cluster_3            NaN          0.0
#                                     cluster_4       1.150487          NaN
#                                     cluster_5            0.0          0.0
#                                     cluster_6            NaN     8.752255
#                                     cluster_7       0.165882          NaN
# capexCap     [1e9 Euro/a]           cluster_0            NaN     0.008585
#                                     cluster_1       0.008585          NaN
#                                     cluster_2            0.0     0.000857
#                                     cluster_3            NaN          0.0
#                                     cluster_4        0.00263          NaN
#                                     cluster_5            0.0          0.0
#                                     cluster_6            NaN     0.019812
#                                     cluster_7       0.000241          NaN
# capexIfBuilt [1e9 Euro/a]           cluster_0            NaN      0.00512
#                                     cluster_1        0.00512          NaN
#                                     cluster_2            0.0     0.002767
#                                     cluster_3            NaN          0.0
#                                     cluster_4       0.004262          NaN
#                                     cluster_5            0.0          0.0
#                                     cluster_6            NaN      0.00422
#                                     cluster_7       0.002712          NaN
# invest       [1e9 Euro]             cluster_0            NaN     0.163422
#                                     cluster_1       0.163422          NaN
#                                     cluster_2            0.0     0.043217
#                                     cluster_3            NaN          0.0
#                                     cluster_4        0.08218          NaN
#                                     cluster_5            0.0          0.0
#                                     cluster_6            NaN      0.28657
#                                     cluster_7       0.035217          NaN
# isBuilt      [-]                    cluster_0            NaN          1.0
#                                     cluster_1            1.0          NaN
#                                     cluster_2            0.0          1.0
#                                     cluster_3            NaN          0.0
#                                     cluster_4            1.0          NaN
#                                     cluster_5            0.0          0.0
#                                     cluster_6            NaN          1.0
#                                     cluster_7            1.0          NaN
# operation    [GW$_{H_{2},LHV}$*h/a] cluster_0            NaN          0.0
#                                     cluster_1   27386.620783          NaN
#                                     cluster_3            NaN          0.0
#                                     cluster_6            NaN  59027.64601
#              [GW$_{H_{2},LHV}$*h]   cluster_0            NaN          0.0
#                                     cluster_1   27386.620783          NaN
#                                     cluster_3            NaN          0.0
#                                     cluster_6            NaN  59027.64601
#
#                                                   cluster_2     cluster_3  \
# Property     Unit                   LocationIn
# TAC          [1e9 Euro/a]           cluster_0           0.0           0.0
#                                     cluster_1      0.003624           0.0
#                                     cluster_2           0.0           0.0
#                                     cluster_3           0.0           0.0
#                                     cluster_4           0.0           0.0
#                                     cluster_5           0.0      0.005462
#                                     cluster_6           0.0      0.008896
#                                     cluster_7           0.0           0.0
# capacity     [GW$_{H_{2},LHV}$]     cluster_0           0.0           NaN
#                                     cluster_1      0.577217           0.0
#                                     cluster_2           NaN           NaN
#                                     cluster_3           NaN           NaN
#                                     cluster_4           NaN           NaN
#                                     cluster_5           NaN      0.656099
#                                     cluster_6           NaN      1.257027
#                                     cluster_7           0.0           NaN
# capexCap     [1e9 Euro/a]           cluster_0           0.0           NaN
#                                     cluster_1      0.000857           0.0
#                                     cluster_2           NaN           NaN
#                                     cluster_3           NaN           NaN
#                                     cluster_4           NaN           NaN
#                                     cluster_5           NaN      0.001422
#                                     cluster_6           NaN      0.003582
#                                     cluster_7           0.0           NaN
# capexIfBuilt [1e9 Euro/a]           cluster_0           0.0           NaN
#                                     cluster_1      0.002767           0.0
#                                     cluster_2           NaN           NaN
#                                     cluster_3           NaN           NaN
#                                     cluster_4           NaN           NaN
#                                     cluster_5           NaN       0.00404
#                                     cluster_6           NaN      0.005313
#                                     cluster_7           0.0           NaN
# invest       [1e9 Euro]             cluster_0           0.0           NaN
#                                     cluster_1      0.043217           0.0
#                                     cluster_2           NaN           NaN
#                                     cluster_3           NaN           NaN
#                                     cluster_4           NaN           NaN
#                                     cluster_5           NaN      0.065135
#                                     cluster_6           NaN      0.106079
#                                     cluster_7           0.0           NaN
# isBuilt      [-]                    cluster_0           0.0           NaN
#                                     cluster_1           1.0           0.0
#                                     cluster_2           NaN           NaN
#                                     cluster_3           NaN           NaN
#                                     cluster_4           NaN           NaN
#                                     cluster_5           NaN           1.0
#                                     cluster_6           NaN           1.0
#                                     cluster_7           0.0           NaN
# operation    [GW$_{H_{2},LHV}$*h/a] cluster_0           0.0           NaN
#                                     cluster_1   3566.092714           0.0
#                                     cluster_3           NaN           NaN
#                                     cluster_6           NaN  11011.555436
#              [GW$_{H_{2},LHV}$*h]   cluster_0           0.0           NaN
#                                     cluster_1   3566.092714           0.0
#                                     cluster_3           NaN           NaN
#                                     cluster_6           NaN  11011.555436
#
#                                                    cluster_4    cluster_5  \
# Property     Unit                   LocationIn
# TAC          [1e9 Euro/a]           cluster_0       0.006892          0.0
#                                     cluster_1            0.0          0.0
#                                     cluster_2            0.0          0.0
#                                     cluster_3            0.0     0.005462
#                                     cluster_4            0.0          0.0
#                                     cluster_5            0.0          0.0
#                                     cluster_6            0.0          0.0
#                                     cluster_7            0.0          0.0
# capacity     [GW$_{H_{2},LHV}$]     cluster_0       1.150487          0.0
#                                     cluster_1            NaN          0.0
#                                     cluster_2            NaN          NaN
#                                     cluster_3            NaN     0.656099
#                                     cluster_4            NaN          0.0
#                                     cluster_5            0.0          NaN
#                                     cluster_6            NaN          NaN
#                                     cluster_7            NaN          NaN
# capexCap     [1e9 Euro/a]           cluster_0        0.00263          0.0
#                                     cluster_1            NaN          0.0
#                                     cluster_2            NaN          NaN
#                                     cluster_3            NaN     0.001422
#                                     cluster_4            NaN          0.0
#                                     cluster_5            0.0          NaN
#                                     cluster_6            NaN          NaN
#                                     cluster_7            NaN          NaN
# capexIfBuilt [1e9 Euro/a]           cluster_0       0.004262          0.0
#                                     cluster_1            NaN          0.0
#                                     cluster_2            NaN          NaN
#                                     cluster_3            NaN      0.00404
#                                     cluster_4            NaN          0.0
#                                     cluster_5            0.0          NaN
#                                     cluster_6            NaN          NaN
#                                     cluster_7            NaN          NaN
# invest       [1e9 Euro]             cluster_0        0.08218          0.0
#                                     cluster_1            NaN          0.0
#                                     cluster_2            NaN          NaN
#                                     cluster_3            NaN     0.065135
#                                     cluster_4            NaN          0.0
#                                     cluster_5            0.0          NaN
#                                     cluster_6            NaN          NaN
#                                     cluster_7            NaN          NaN
# isBuilt      [-]                    cluster_0            1.0          0.0
#                                     cluster_1            NaN          0.0
#                                     cluster_2            NaN          NaN
#                                     cluster_3            NaN          1.0
#                                     cluster_4            NaN          0.0
#                                     cluster_5            0.0          NaN
#                                     cluster_6            NaN          NaN
#                                     cluster_7            NaN          NaN
# operation    [GW$_{H_{2},LHV}$*h/a] cluster_0   10078.267525          0.0
#                                     cluster_1            NaN          0.0
#                                     cluster_3            NaN  5747.423572
#                                     cluster_6            NaN          NaN
#              [GW$_{H_{2},LHV}$*h]   cluster_0   10078.267525          0.0
#                                     cluster_1            NaN          0.0
#                                     cluster_3            NaN  5747.423572
#                                     cluster_6            NaN          NaN
#
#                                                    cluster_6    cluster_7
# Property     Unit                   LocationIn
# TAC          [1e9 Euro/a]           cluster_0            0.0     0.002953
#                                     cluster_1       0.024032          0.0
#                                     cluster_2            0.0          0.0
#                                     cluster_3       0.008896          0.0
#                                     cluster_4            0.0          0.0
#                                     cluster_5            0.0          0.0
#                                     cluster_6            0.0          0.0
#                                     cluster_7            0.0          0.0
# capacity     [GW$_{H_{2},LHV}$]     cluster_0            NaN     0.165882
#                                     cluster_1       8.752255          NaN
#                                     cluster_2            NaN          0.0
#                                     cluster_3       1.257027          NaN
#                                     cluster_4            NaN          NaN
#                                     cluster_5            NaN          NaN
#                                     cluster_6            NaN          NaN
#                                     cluster_7            NaN          NaN
# capexCap     [1e9 Euro/a]           cluster_0            NaN     0.000241
#                                     cluster_1       0.019812          NaN
#                                     cluster_2            NaN          0.0
#                                     cluster_3       0.003582          NaN
#                                     cluster_4            NaN          NaN
#                                     cluster_5            NaN          NaN
#                                     cluster_6            NaN          NaN
#                                     cluster_7            NaN          NaN
# capexIfBuilt [1e9 Euro/a]           cluster_0            NaN     0.002712
#                                     cluster_1        0.00422          NaN
#                                     cluster_2            NaN          0.0
#                                     cluster_3       0.005313          NaN
#                                     cluster_4            NaN          NaN
#                                     cluster_5            NaN          NaN
#                                     cluster_6            NaN          NaN
#                                     cluster_7            NaN          NaN
# invest       [1e9 Euro]             cluster_0            NaN     0.035217
#                                     cluster_1        0.28657          NaN
#                                     cluster_2            NaN          0.0
#                                     cluster_3       0.106079          NaN
#                                     cluster_4            NaN          NaN
#                                     cluster_5            NaN          NaN
#                                     cluster_6            NaN          NaN
#                                     cluster_7            NaN          NaN
# isBuilt      [-]                    cluster_0            NaN          1.0
#                                     cluster_1            1.0          NaN
#                                     cluster_2            NaN          0.0
#                                     cluster_3            1.0          NaN
#                                     cluster_4            NaN          NaN
#                                     cluster_5            NaN          NaN
#                                     cluster_6            NaN          NaN
#                                     cluster_7            NaN          NaN
# operation    [GW$_{H_{2},LHV}$*h/a] cluster_0            NaN  1453.124166
#                                     cluster_1   17067.875631          NaN
#                                     cluster_3            0.0          NaN
#                                     cluster_6            NaN          NaN
#              [GW$_{H_{2},LHV}$*h]   cluster_0            NaN  1453.124166
#                                     cluster_1   17067.875631          NaN
#                                     cluster_3            0.0          NaN
#                                     cluster_6            NaN          NaN

# %% [markdown]
# Check that the shared capacity of the pipelines are not exceeded

# %%
df=esM.componentModelingDict["TransmissionModel"].capacityVariablesOptimum
df.loc['Pipelines (biogas)']+df.loc['Pipelines (hydrogen)']
# Out:
#            cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  \
# cluster_0        NaN   3.126327   1.299364        NaN   1.892217   0.000000
# cluster_1   3.126327        NaN   0.577217   0.000000        NaN   0.000000
# cluster_2   1.299364   0.577217        NaN        NaN        NaN        NaN
# cluster_3        NaN   0.000000        NaN        NaN        NaN   0.656099
# cluster_4   1.892217        NaN        NaN        NaN        NaN   0.000000
# cluster_5   0.000000   0.000000        NaN   0.656099   0.000000        NaN
# cluster_6        NaN   9.100215        NaN   1.257027        NaN        NaN
# cluster_7   0.165882        NaN   0.139259        NaN        NaN        NaN
#
#            cluster_6  cluster_7
# cluster_0        NaN   0.165882
# cluster_1   9.100215        NaN
# cluster_2        NaN   0.139259
# cluster_3   1.257027        NaN
# cluster_4        NaN        NaN
# cluster_5        NaN        NaN
# cluster_6        NaN        NaN
# cluster_7        NaN        NaN

# %% [markdown]
# Plot installed transmission capacities

# %%
transFilePath = os.path.join(cwd, 'InputData', 'SpatialData','ShapeFiles', 'AClines.shp')

fig, ax = fn.plotLocations(locFilePath, indexColumn='index')                                 
fig, ax = fn.plotTransmission(esM, 'AC cables', transFilePath, loc0='bus0', loc1='bus1', fig=fig, ax=ax)
save_figure(fig, 'Installed_ac_cables')

# %%
transFilePath = os.path.join(cwd, 'InputData', 'SpatialData','ShapeFiles', 'DClines.shp')

fig, ax = fn.plotLocations(locFilePath, indexColumn='index')                                 
fig, ax = fn.plotTransmission(esM, 'DC cables', transFilePath, loc0='cluster0', loc1='cluster1', fig=fig, ax=ax)
save_figure(fig, 'Installed_dc_cables')

# %%
transFilePath = os.path.join(cwd, 'InputData', 'SpatialData','ShapeFiles', 'transmissionPipeline.shp')

fig, ax = fn.plotLocations(locFilePath, indexColumn='index')                                 
fig, ax = fn.plotTransmission(esM, 'Pipelines (hydrogen)', transFilePath, loc0='loc1', loc1='loc2',
                              fig=fig, ax=ax)
save_figure(fig, 'Installed_hydro_pipelines')

# %%
transFilePath = os.path.join(cwd, 'InputData', 'SpatialData','ShapeFiles', 'transmissionPipeline.shp')

fig, ax = fn.plotLocations(locFilePath, indexColumn='index')                                 
fig, ax = fn.plotTransmission(esM, 'Pipelines (biogas)', transFilePath, loc0='loc1', loc1='loc2',
                              fig=fig, ax=ax)
save_figure(fig, 'Installed_biogas_pipelines')

# %% [markdown]
# # Postprocessing: Determine robust pipeline design

# %%
# Import module expansion "robustPipelineSizing"
from FINE.expansionModules import robustPipelineSizing

# %%
# 1. Option to get the injection and withdrawal rates for the pipeline sizing (in kg/s)
rates = robustPipelineSizing.getInjectionWithdrawalRates(componentName='Pipelines (hydrogen)',esM=esM) # in GWh
# Convert GWh to kg/s: GWh * (kWh/GWh) * (kg/kWh) * (1/ timestepLengthInSeconds) with timestepLengthInSeconds
# being 3600 seconds for the present example
rates = rates * (10 ** 6) * (1/33.32) * (1/3600)
rates.head()
# Out:
#    cluster_7  cluster_5  cluster_4  cluster_3  cluster_6  cluster_2  \
# 0   1.382901   5.469676   9.591229    5.00974 -35.063804   4.812069
# 1   1.382901   5.469676   9.591229    5.00974 -38.337817   4.812069
# 2   1.382901   5.469676   9.591229    5.00974 -51.829766   4.812069
# 3   1.382901   5.469676   9.591229    5.00974 -38.582307   4.812069
# 4   1.382901   5.469676   9.591229    5.00974 -44.310027   4.812069
#
#    cluster_1  cluster_0
# 0  -6.290828  15.089016
# 1  -3.016814  15.089016
# 2  10.475135  15.089016
# 3  -2.772324  15.089016
# 4   2.955396  15.089016

# %%
# 2. Option to get the injection and withdrawal rates for the pipeline sizing (in kg/s)
op = esM.componentModelingDict[esM.componentNames['Pipelines (hydrogen)']].\
    getOptimalValues('operationVariablesOptimum')['values'].loc['Pipelines (hydrogen)']
rates = robustPipelineSizing.getInjectionWithdrawalRates(operationVariablesOptimumData=op) # in GWh
# Convert GWh to kg/s: GWh * (kWh/GWh) * (kg/kWh) * (1/ timestepLengthInSeconds) with timestepLengthInSeconds
# being 3600 seconds for the present example
rates = rates * (10 ** 6) * (1/33.32) * (1/3600)
rates.head()
# Out:
#    cluster_0  cluster_1  cluster_2  cluster_4  cluster_5  cluster_7  \
# 0  15.089016  -6.290828   4.812069   9.591229   5.469676   1.382901
# 1  15.089016  -3.016814   4.812069   9.591229   5.469676   1.382901
# 2  15.089016  10.475135   4.812069   9.591229   5.469676   1.382901
# 3  15.089016  -2.772324   4.812069   9.591229   5.469676   1.382901
# 4  15.089016   2.955396   4.812069   9.591229   5.469676   1.382901
#
#    cluster_3  cluster_6
# 0    5.00974 -35.063804
# 1    5.00974 -38.337817
# 2    5.00974 -51.829766
# 3    5.00974 -38.582307
# 4    5.00974 -44.310027

# %%
# Determine unique withdrawal and injection scenarios to save computation time
rates = rates.drop_duplicates()
rates.head()
# Out:
#    cluster_0  cluster_1  cluster_2  cluster_4  cluster_5  cluster_7  \
# 0  15.089016  -6.290828   4.812069   9.591229   5.469676   1.382901
# 1  15.089016  -3.016814   4.812069   9.591229   5.469676   1.382901
# 2  15.089016  10.475135   4.812069   9.591229   5.469676   1.382901
# 3  15.089016  -2.772324   4.812069   9.591229   5.469676   1.382901
# 4  15.089016   2.955396   4.812069   9.591229   5.469676   1.382901
#
#    cluster_3  cluster_6
# 0    5.00974 -35.063804
# 1    5.00974 -38.337817
# 2    5.00974 -51.829766
# 3    5.00974 -38.582307
# 4    5.00974 -44.310027

# %%
# Get the lengths of the pipeline (in m)
lengths = robustPipelineSizing.getNetworkLengthsFromESM('Pipelines (hydrogen)', esM)
lengths = lengths * 1e3
lengths.head()
# Out:
# (cluster_0, cluster_1)    370000.0
# (cluster_0, cluster_2)    336000.0
# (cluster_0, cluster_4)    308000.0
# (cluster_0, cluster_5)    501000.0
# (cluster_0, cluster_7)    196000.0
# dtype: float64

# %%
# Specify minimum and maximum pressure levels for all injection and withdrawal nodes (in bar)
p_min_nodes = {'cluster_5': 60, 'cluster_3': 50, 'cluster_7': 50, 'cluster_1': 60, 'cluster_6': 50,
               'cluster_4': 50, 'cluster_0': 50, 'cluster_2': 50}

p_max_nodes = {'cluster_5': 100, 'cluster_3': 100, 'cluster_7': 100, 'cluster_1': 90, 'cluster_6': 100,
               'cluster_4': 100, 'cluster_0': 100, 'cluster_2': 100}

# %%
# Specify the investment cost of the available diameter classes in €/m

# For single pipes
dic_diameter_costs = {0.1063: 37.51, 0.1307: 38.45, 0.1593: 39.64, 0.2065: 42.12,
                      0.2588: 45.26, 0.3063: 48.69, 0.3356: 51.07, 0.3844: 55.24,
                      0.432: 59.86, 0.4796: 64.98, 0.527: 70.56, 0.578: 76.61,
                      0.625: 82.99, 0.671: 89.95, 0.722: 97.38, 0.7686: 105.28,
                      0.814: 113.63, 0.864: 122.28, 0.915: 131.56, 0.96: 141.3,
                      1.011: 151.5, 1.058: 162.17, 1.104: 173.08, 1.155: 184.67,
                      1.249: 209.24, 1.342: 235.4, 1.444: 263.66, 1.536: 293.78}

# For parallel pipes
dic_candidateMergedDiam_costs={1.342: 235.4, 1.444: 263.66, 1.536: 293.78}

# %%
# Choose if a robust pipeline desin should be determined or the design should be optimized based on the
# given injection and withdrawal rates only
robust = True

# %% [markdown]
# ### Determine design for simple network structure

# %%
# Compute with 7 threads and simple network structure

dic_arc_optimalDiameters, dic_scen_PressLevels, dic_scen_MaxViolPress, dic_timeStep_PressLevels, \
    dic_timeStep_MaxViolPress, _ = robustPipelineSizing.determineDiscretePipelineDesign(
        robust=robust, injectionWithdrawalRates=rates,
        distances=lengths, dic_node_minPress=p_min_nodes, dic_node_maxPress=p_max_nodes,
        dic_diameter_costs=dic_diameter_costs, dic_candidateMergedDiam_costs=dic_candidateMergedDiam_costs,
        threads=7)
# Out:
# Creating graph with respect to given distances
# Original Network Graph:
# Creating a Steiner treee
# Steiner tree:
# Compute robust scenario set for tree network (based on 56 node combinations). Threads: 7
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\expansionModules\robustPipelineSizing.py", line 507, in _generateRobustScenarios
#     return startNode_endNode, computeSingleSpecialScenario(startNode=startNode, endNode=endNode, **kwargs)
#   File "C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\expansionModules\robustPipelineSizing.py", line 673, in computeSingleSpecialScenario
#     model.Nodes = py.Set(initialize=graph.nodes)
#   File "C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\pyomo\core\base\block.py", line 541, in __setattr__
#     self.add_component(name, val)
#   File "C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\pyomo\core\base\block.py", line 1086, in add_component
#     val.construct(data)
#   File "C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\pyomo\core\base\disable_methods.py", line 115, in construct
#     return base.construct(self, data)
#   File "C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\pyomo\core\base\set.py", line 1990, in construct
#     IndexedComponent.__getitem__(self, index)
#   File "C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\pyomo\core\base\indexed_component.py", line 511, in __getitem__
#     validated_index = self._validate_index(index)
#   File "C:\Users\Paul\.conda\envs\gas-wasserstoff3\lib\site-packages\pyomo\core\base\indexed_component.py", line 732, in _validate_index
#     "as an indexed component" % ( self.name, ))
# KeyError: "Cannot treat the scalar component 'Nodes' as an indexed component"
# """
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8312/3522726593.py in <module>
#       6         distances=lengths, dic_node_minPress=p_min_nodes, dic_node_maxPress=p_max_nodes,
#       7         dic_diameter_costs=dic_diameter_costs, dic_candidateMergedDiam_costs=dic_candidateMergedDiam_costs,
# ----> 8         threads=7)
#       9
#
# ~\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\expansionModules\robustPipelineSizing.py in determineDiscretePipelineDesign(robust, injectionWithdrawalRates, distances, dic_node_minPress, dic_node_maxPress, dic_diameter_costs, dic_candidateMergedDiam_costs, gdfEdges, regColumn1, regColumn2, solver, opexForDiameters, economicLifetime, interestRate, costUnit, ir, rho_n, T_m, T_n, p_n, Z_n, originalFluidFlows, nDigits, verbose, threads)
#    2106     timeStart = time.time()
#    2107     dic_nodePair_flows, entries, exits = generateRobustScenarios(injectionWithdrawalRates, graph, distances,
# -> 2108         dic_node_minPress, dic_node_maxPress, solver=solver, threads=threads, verbose=verbose)
#    2109     utils.output("Number of robust scenarios: " + str(len(dic_nodePair_flows.keys())) , verbose, 0)
#    2110     utils.output("\t\t(%.4f" % (time.time() - timeStart) + " sec)\n", verbose, 0)
#
# ~\.conda\envs\gas-wasserstoff3\lib\site-packages\FINE\expansionModules\robustPipelineSizing.py in generateRobustScenarios(injectionWithdrawalRates, graph, distances, dic_node_minPress, dic_node_maxPress, solver, threads, verbose)
#     595                                                 entries=entries, exits=exits, dic_nodes_MinCapacity=dic_nodes_MinCapacity,
#     596                                                 dic_nodes_MaxCapacity=dic_nodes_MaxCapacity, solver=solver),
# --> 597                                nodes), 1):
#     598         if verbose == 0:
#     599             sys.stderr.write('\rPercentage simulated: {:d}%'.format(int(i / len(nodes) * 100)))
#
# ~\.conda\envs\gas-wasserstoff3\lib\multiprocessing\pool.py in next(self, timeout)
#     746         if success:
#     747             return value
# --> 748         raise value
#     749
#     750     __next__ = next                    # XXX
#
# KeyError: "Cannot treat the scalar component 'Nodes' as an indexed component"

# %%
# Compute with 2 threads and simple network structure

dic_arc_optimalDiameters, dic_scen_PressLevels, dic_scen_MaxViolPress, dic_timeStep_PressLevels, \
    dic_timeStep_MaxViolPress, _ = robustPipelineSizing.determineDiscretePipelineDesign(
        robust=robust, injectionWithdrawalRates=rates,
        distances=lengths, dic_node_minPress=p_min_nodes, dic_node_maxPress=p_max_nodes,
        dic_diameter_costs=dic_diameter_costs, dic_candidateMergedDiam_costs=dic_candidateMergedDiam_costs,
        threads=2)

print("Finished Discrete Pipeline Optimization")

# %% [markdown]
# ### Determine design for more complex network structure

# %%
# Redfine minimum and maximum pressure levels to reduce robust scenario computation time
p_min_nodes = {'cluster_5': 50, 'cluster_3': 50, 'cluster_7': 50, 'cluster_1': 50, 'cluster_6': 50,
               'cluster_4': 50, 'cluster_0': 50, 'cluster_2': 50}

p_max_nodes = {'cluster_5': 100, 'cluster_3': 100, 'cluster_7': 100, 'cluster_1': 100, 'cluster_6': 100,
               'cluster_4': 100, 'cluster_0': 100, 'cluster_2': 100}

# %%
# Get more complex network structure
regColumn1 = 'loc1'
regColumn2 = 'loc2'

dic_node_minPress=p_min_nodes
dic_node_maxPress=p_max_nodes

maxPipeLength= 35 * 1e3
minPipeLength= 1 * 1e3

distances_new, dic_node_minPress_new, dic_node_maxPress_new, gdfNodes, gdfEdges = \
    robustPipelineSizing.getRefinedShapeFile(transFilePath, regColumn1, regColumn2, dic_node_minPress,
                                             dic_node_maxPress, minPipeLength, maxPipeLength)

fig, ax = fn.plotLocations(locFilePath, indexColumn='index')

gdfEdges.plot(ax=ax, color='grey')
gdfNodes.plot(ax=ax, color='red', markersize=2)
ax.axis('off')

plt.show()

# %%
# Determine optimal pipeline design with seven threads
dic_arc_optimalDiameters, dic_scen_PressLevels, dic_scen_MaxViolPress, dic_timeStep_PressLevels, \
           dic_timeStep_MaxViolPress, gdfEdges = robustPipelineSizing.determineDiscretePipelineDesign(
        robust=robust, injectionWithdrawalRates=rates,
        distances=distances_new, dic_node_minPress=dic_node_minPress_new, dic_node_maxPress=dic_node_maxPress_new,
        dic_diameter_costs=dic_diameter_costs, dic_candidateMergedDiam_costs=dic_candidateMergedDiam_costs,
        gdfEdges=gdfEdges, regColumn1='nodeIn', regColumn2='nodeOut', threads=7, solver='gurobi')

# %% [markdown]
# ### Plot scenario output

# %%
# Get regions shapefile as geopandas GeoDataFrame
gdf_regions = gpd.read_file(locFilePath)

# %%
# Visualize pipeline diameters
fig, ax =robustPipelineSizing.plotOptimizedNetwork(gdfEdges, gdf_regions=gdf_regions, figsize=(5,5),
    line_scaling=0.8)

# %%
# Get a minimum and maximum pressure scenario
dic_timeStep_PressLevels = pd.DataFrame.from_dict(dic_scen_PressLevels)

scen_min = dic_timeStep_PressLevels.mean().min()
scen_min = dic_timeStep_PressLevels.loc[:,dic_timeStep_PressLevels.mean() == scen_min].iloc[:,0]
scen_max = dic_timeStep_PressLevels.mean().max()
scen_max = dic_timeStep_PressLevels.loc[:,dic_timeStep_PressLevels.mean() == scen_max].iloc[:,0]

# %%
fig, ax =robustPipelineSizing.plotOptimizedNetwork(gdfEdges, gdf_regions=gdf_regions, figsize=(5,5),
    line_scaling=0.9, pressureLevels=scen_min)

# %%
fig, ax =robustPipelineSizing.plotOptimizedNetwork(gdfEdges, gdf_regions=gdf_regions, figsize=(5,5),
    line_scaling=0.9, pressureLevels=scen_max)
